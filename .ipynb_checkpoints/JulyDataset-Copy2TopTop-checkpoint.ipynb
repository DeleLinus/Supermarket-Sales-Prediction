# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
file_path='train.csv'
df=pd.read_csv(file_path)
df.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRB24            CHUKWUDI017              DRB24_CHUKWUDI017
# 1              FDR31            CHUKWUDI019              FDR31_CHUKWUDI019
# 2              FDP16            CHUKWUDI017              FDP16_CHUKWUDI017
# 3              FDY16            CHUKWUDI027              FDY16_CHUKWUDI027
# 4              FDY48            CHUKWUDI046              FDY48_CHUKWUDI046
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility  \
# 0           8.785             Low Fat                  0.020694
# 1             NaN          Normal Fat                  0.086078
# 2          18.600             Low Fat                  0.039517
# 3             NaN          Normal Fat                  0.091780
# 4          14.000             Low Fat                  0.023735
#
#             Product_Type  Product_Price  Supermarket_Opening_Year  \
# 0            Soft Drinks         382.91                      2014
# 1  Fruits and Vegetables         359.53                      1992
# 2           Frozen Foods         609.20                      2014
# 3           Frozen Foods         456.32                      1992
# 4           Baking Goods         258.08                      2004
#
#   Supermarket _Size Supermarket_Location_Type   Supermarket_Type  \
# 0               NaN                 Cluster 2  Supermarket Type1
# 1             Small                 Cluster 1      Grocery Store
# 2               NaN                 Cluster 2  Supermarket Type1
# 3            Medium                 Cluster 3  Supermarket Type3
# 4             Small                 Cluster 1  Supermarket Type1
#
#    Product_Supermarket_Sales
# 0                    4633.97
# 1                     729.05
# 2                   14740.81
# 3                   16137.33
# 4                    4613.99

# %%
path='test.csv'
df2=pd.read_csv(path)
df2.head()
# df2.isnull().sum()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              FDC15            CHUKWUDI049              FDC15_CHUKWUDI049
# 1              NCY06            CHUKWUDI018              NCY06_CHUKWUDI018
# 2              DRB24            CHUKWUDI035              DRB24_CHUKWUDI035
# 3              NCG54            CHUKWUDI018              NCG54_CHUKWUDI018
# 4              NCA42            CHUKWUDI017              NCA42_CHUKWUDI017
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0          18.100             Low Fat                  0.178246        Dairy
# 1          15.250             Low Fat                  0.061434    Household
# 2           8.785             Low Fat                  0.020573  Soft Drinks
# 3          12.100             Low Fat                  0.080131    Household
# 4           6.965             Low Fat                  0.028710    Household
#
#    Product_Price  Supermarket_Opening_Year Supermarket _Size  \
# 0         395.32                      2006            Medium
# 1         327.49                      2016            Medium
# 2         391.16                      2011             Small
# 3         427.28                      2016            Medium
# 4         395.40                      2014               NaN
#
#   Supermarket_Location_Type   Supermarket_Type
# 0                 Cluster 1  Supermarket Type1
# 1                 Cluster 3  Supermarket Type2
# 2                 Cluster 2  Supermarket Type1
# 3                 Cluster 3  Supermarket Type2
# 4                 Cluster 2  Supermarket Type1

# %%
df.describe(include='all')
# Out:
#        Product_Identifier Supermarket_Identifier  \
# count                3742                   3742
# unique               1367                     10
# top                 NCL31            CHUKWUDI017
# freq                    9                    461
# mean                  NaN                    NaN
# std                   NaN                    NaN
# min                   NaN                    NaN
# 25%                   NaN                    NaN
# 50%                   NaN                    NaN
# 75%                   NaN                    NaN
# max                   NaN                    NaN
#
#        Product_Supermarket_Identifier  Product_Weight Product_Fat_Content  \
# count                            3742     3141.000000                3742
# unique                           3742             NaN                   3
# top                 FDM36_CHUKWUDI017             NaN             Low Fat
# freq                                1             NaN                2272
# mean                              NaN       12.870640                 NaN
# std                               NaN        4.730432                 NaN
# min                               NaN        4.555000                 NaN
# 25%                               NaN        8.630000                 NaN
# 50%                               NaN       12.600000                 NaN
# 75%                               NaN       17.100000                 NaN
# max                               NaN       21.350000                 NaN
#
#         Product_Shelf_Visibility Product_Type  Product_Price  \
# count                3742.000000         3742    3742.000000
# unique                       NaN           16            NaN
# top                          NaN  Snack Foods            NaN
# freq                         NaN          563            NaN
# mean                    0.066613          NaN     391.815315
# std                     0.052951          NaN     120.204222
# min                     0.000000          NaN      78.730000
# 25%                     0.026971          NaN     308.392500
# 50%                     0.053517          NaN     393.910000
# 75%                     0.095094          NaN     466.480000
# max                     0.328391          NaN     667.220000
#
#         Supermarket_Opening_Year Supermarket _Size Supermarket_Location_Type  \
# count                3742.000000              2616                      3742
# unique                       NaN                 3                         3
# top                          NaN            Medium                 Cluster 3
# freq                         NaN              1155                      1438
# mean                 2004.778461               NaN                       NaN
# std                     8.276712               NaN                       NaN
# min                  1992.000000               NaN                       NaN
# 25%                  1994.000000               NaN                       NaN
# 50%                  2006.000000               NaN                       NaN
# 75%                  2011.000000               NaN                       NaN
# max                  2016.000000               NaN                       NaN
#
#          Supermarket_Type  Product_Supermarket_Sales
# count                3742                3742.000000
# unique                  4                        NaN
# top     Supermarket Type1                        NaN
# freq                 2495                        NaN
# mean                  NaN                6103.735353
# std                   NaN                4456.169125
# min                   NaN                  83.230000
# 25%                   NaN                2728.120000
# 50%                   NaN                5374.675000
# 75%                   NaN                8524.737500
# max                   NaN               28612.760000

# %% [markdown]
# # Treating Missing Values

# %%
# df.isnull().sum()

# df2.isnull().sum()

#check the mode of the supermarket size values
# df['Supermarket _Size'].value_counts().idxmax()

# df2['Supermarket _Size'].value_counts().idxmax()

#replace the missing 'Supermarket_Size' values by the most frequent 
df["Supermarket _Size"].replace(np.nan, "Medium", inplace=True)
df2["Supermarket _Size"].replace(np.nan, "Medium", inplace=True)
df.Product_Weight=df.sort_values(['Product_Identifier','Product_Weight']).Product_Weight.ffill( )
df2.Product_Weight=df.sort_values(['Product_Identifier','Product_Weight']).Product_Weight.ffill( )

# %%
# group 'Product_Identifier', 'Product_Weight' by 'Product_Identifier' so as to replace nan with the mean
#of the corresponding 'Product_Identifier'
df_gptest = df[['Product_Identifier', 'Product_Weight']]
grouped_test1 = df_gptest.groupby(['Product_Identifier'],as_index=False).mean()

# %%
df.sort_values(['Product_Identifier','Supermarket_Identifier']).head()
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 183               DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1391              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2103              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 1719              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
# 2592              DRA12            CHUKWUDI045              DRA12_CHUKWUDI045
#
#       Product_Weight Product_Fat_Content  Product_Shelf_Visibility  \
# 183             11.6             Low Fat                  0.068535
# 1391            11.6             Low Fat                  0.040912
# 2103            11.6             Low Fat                  0.041178
# 1719            11.6       Ultra Low fat                  0.000000
# 2592            11.6             Low Fat                  0.000000
#
#      Product_Type  Product_Price  Supermarket_Opening_Year Supermarket _Size  \
# 183   Soft Drinks         357.54                      2005            Medium
# 1391  Soft Drinks         355.79                      1994              High
# 2103  Soft Drinks         350.79                      2014            Medium
# 1719  Soft Drinks         354.79                      2011             Small
# 2592  Soft Drinks         354.04                      2009            Medium
#
#      Supermarket_Location_Type   Supermarket_Type  Product_Supermarket_Sales
# 183                  Cluster 3      Grocery Store                     709.08
# 1391                 Cluster 3  Supermarket Type1                    6381.69
# 2103                 Cluster 2  Supermarket Type1                    6381.69
# 1719                 Cluster 2  Supermarket Type1                    2481.77
# 2592                 Cluster 2  Supermarket Type1                    9572.54

# %%
df.dtypes
# Out:
# Product_Identifier                 object
# Supermarket_Identifier             object
# Product_Supermarket_Identifier     object
# Product_Weight                    float64
# Product_Fat_Content                object
# Product_Shelf_Visibility          float64
# Product_Type                       object
# Product_Price                     float64
# Supermarket_Opening_Year            int64
# Supermarket _Size                  object
# Supermarket_Location_Type          object
# Supermarket_Type                   object
# Product_Supermarket_Sales         float64
# dtype: object

# %% [markdown]
# # product that gives a better margin at specific stores

# %%
# grouped_1=df[['Product_Type','Supermarket_Identifier','Product_Supermarket_Sales']]
# grpd_1=grouped_1.groupby(['Product_Type','Supermarket_Identifier'],as_index=False).mean()
# grpd_1=grpd_1.sort_values(['Product_Type','Product_Supermarket_Sales'], ascending=False)
# grpd_1

# %%
# grouped_11=df[['Product_Type','Product_Supermarket_Sales']]
# grpd_11=grouped_11.groupby(['Product_Type'],as_index=False).sum()
# grpd_11=grpd_11.sort_values(['Product_Supermarket_Sales'], ascending=False)
# grpd_11

# %%
# grouped_pivot = grpd_1.pivot(index='Product_Type',columns='Supermarket_Identifier')
# grouped_pivot.head()

# %%
# fig, ax = plt.subplots()
# im = ax.pcolor(grouped_pivot, cmap='RdBu')

# #label names
# row_labels = grouped_pivot.columns.levels[1]
# col_labels = grouped_pivot.index

# #move ticks and labels to the center
# ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
# ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

# #insert labels
# ax.set_xticklabels(row_labels, minor=False)
# ax.set_yticklabels(col_labels, minor=False)

# #rotate label if too long
# plt.xticks(rotation=90)

# fig.colorbar(im)
# plt.show()

# %% [markdown]
# # Supermarket Type analysis

# %%
grouped_2=df[['Supermarket_Type', 'Product_Supermarket_Sales']]
grpd_2=grouped_2.groupby(['Supermarket_Type'],as_index=False).mean()
grpd_2.sort_values('Product_Supermarket_Sales',ascending=False)
# Out:
#     Supermarket_Type  Product_Supermarket_Sales
# 3  Supermarket Type3               12541.373382
# 1  Supermarket Type1                6434.596537
# 2  Supermarket Type2                5588.015335
# 0      Grocery Store                 821.426611

# %% [markdown]
# # Encoding

# %%
df['Supermarket_Type'].replace('Supermarket Type3',4, inplace=True)
df['Supermarket_Type'].replace('Supermarket Type1',3, inplace=True)
df['Supermarket_Type'].replace('Supermarket Type2',2, inplace=True)
df['Supermarket_Type'].replace('Grocery Store',1, inplace=True)
# df[['Supermarket_Type']]

df2['Supermarket_Type'].replace('Supermarket Type3',4, inplace=True)
df2['Supermarket_Type'].replace('Supermarket Type1',3, inplace=True)
df2['Supermarket_Type'].replace('Supermarket Type2',2, inplace=True)
df2['Supermarket_Type'].replace('Grocery Store',1, inplace=True)
# df2[['Supermarket_Type']]

# %%
# sns.boxplot(x="Supermarket_Type", y="Product_Supermarket_Sales", data=df)

# %%
# grpd_2=grouped_2.groupby(['Supermarket_Type'],as_index=False)
# f_val, p_val = stats.f_oneway(grpd_2.get_group('Supermarket Type1')['Product_Supermarket_Sales'], grpd_2.get_group('Supermarket Type2')['Product_Supermarket_Sales'], grpd_2.get_group('Supermarket Type3')['Product_Supermarket_Sales'], grpd_2.get_group('Grocery Store')['Product_Supermarket_Sales'])  
# print( "ANOVA results: F=", f_val, ", P =", p_val)

# %%
# df['Supermarket_Type'].value_counts()

# %% [markdown]
# # Supermarket_Location_Type analysis

# %%
grouped_3=df[['Supermarket_Location_Type', 'Product_Supermarket_Sales']]
grpd_3=grouped_3.groupby(['Supermarket_Location_Type'],as_index=False).mean()
grpd_3
# Out:
#   Supermarket_Location_Type  Product_Supermarket_Sales
# 0                 Cluster 1                4907.270494
# 1                 Cluster 2                7581.598620
# 2                 Cluster 3                5770.437719

# %% [markdown]
# # Encoding

# %%
df['Supermarket_Location_Type'].replace('Cluster 2',3, inplace=True)
df['Supermarket_Location_Type'].replace('Cluster 3',2, inplace=True)
df['Supermarket_Location_Type'].replace('Cluster 1',1, inplace=True)
# df['Supermarket_Location_Type'].value_counts()

df2['Supermarket_Location_Type'].replace('Cluster 2',3, inplace=True)
df2['Supermarket_Location_Type'].replace('Cluster 3',2, inplace=True)
df2['Supermarket_Location_Type'].replace('Cluster 1',1, inplace=True)
# df2['Supermarket_Location_Type'].value_counts()

# %%
# df['Supermarket_Location_Type'].value_counts()

# %%
sns.boxplot(x="Supermarket_Location_Type", y="Product_Supermarket_Sales", data=df)

# %%
# grpd_3=grouped_3.groupby(['Supermarket_Location_Type'],as_index=False)
# f_val, p_val = stats.f_oneway(grpd_3.get_group('Cluster 1')['Product_Supermarket_Sales'], grpd_3.get_group('Cluster 2')['Product_Supermarket_Sales'], grpd_3.get_group('Cluster 3')['Product_Supermarket_Sales'])  
# print( "ANOVA results: F=", f_val, ", P =", p_val)

# %% [markdown]
# # Product_Fat_Content analysis

# %%
df['Product_Fat_Content'].value_counts()
# Out:
# Low Fat          2272
# Normal Fat       1341
# Ultra Low fat     129
# Name: Product_Fat_Content, dtype: int64

# %%
grouped_4=df[['Product_Fat_Content', 'Product_Supermarket_Sales']]
grpd_4=grouped_4.groupby(['Product_Fat_Content'],as_index=False).mean()
grpd_4
# Out:
#   Product_Fat_Content  Product_Supermarket_Sales
# 0             Low Fat                6038.504696
# 1          Normal Fat                6287.411447
# 2       Ultra Low fat                5343.226899

# %% [markdown]
# # Encoding

# %%
df['Product_Fat_Content'].replace('Low Fat',3, inplace=True)
df['Product_Fat_Content'].replace('Normal Fat',2, inplace=True)
df['Product_Fat_Content'].replace('Ultra Low fat',1, inplace=True)
# df['Product_Fat_Content'].value_counts()
df2['Product_Fat_Content'].replace('Low Fat',3, inplace=True)
df2['Product_Fat_Content'].replace('Normal Fat',2, inplace=True)
df2['Product_Fat_Content'].replace('Ultra Low fat',1, inplace=True)
# df2['Product_Fat_Content'].value_counts()

# %%
# sns.boxplot(x='Product_Fat_Content', y='Product_Supermarket_Sales', data=df)

# %%
# grpd_4=grouped_4.groupby(['Product_Fat_Content'],as_index=False)
# f_val, p_val = stats.f_oneway(grpd_4.get_group('Low Fat')['Product_Supermarket_Sales'], grpd_4.get_group('Normal Fat')['Product_Supermarket_Sales'], grpd_4.get_group('Ultra Low fat')['Product_Supermarket_Sales'])  
# print( "ANOVA results: F=", f_val, ", P =", p_val)

# %% [markdown]
# # supermarket_size analysis

# %%
df['Supermarket _Size'].value_counts()
# Out:
# Medium    2281
# Small     1015
# High       446
# Name: Supermarket _Size, dtype: int64

# %%
grouped_5=df[['Supermarket _Size', 'Product_Supermarket_Sales']]
grpd_5=grouped_5.groupby(['Supermarket _Size'],as_index=False).mean()
grpd_5
# Out:
#   Supermarket _Size  Product_Supermarket_Sales
# 0              High                3998.670359
# 1            Medium                6844.184498
# 2             Small                5364.715143

# %% [markdown]
# # Encoding

# %%
df['Supermarket _Size'].replace('Medium',3, inplace=True)
df['Supermarket _Size'].replace('Small',2, inplace=True)
df['Supermarket _Size'].replace('High',1, inplace=True)

df2['Supermarket _Size'].replace('Medium',3, inplace=True)
df2['Supermarket _Size'].replace('Small',2, inplace=True)
df2['Supermarket _Size'].replace('High',1, inplace=True)

# %%
sns.boxplot(x='Supermarket _Size', y='Product_Supermarket_Sales', data=df)

# %%
# grpd_5=grouped_5.groupby(['Supermarket _Size'],as_index=False)
# f_val, p_val = stats.f_oneway(grpd_5.get_group('Medium')['Product_Supermarket_Sales'], grpd_5.get_group('Small')['Product_Supermarket_Sales'],grpd_5.get_group('High')['Product_Supermarket_Sales'])  
# print( "ANOVA results: F=", f_val, ", P =", p_val)

# %% [markdown]
# # Product_Type analysis

# %%
df['Product_Type'].value_counts()
# Out:
# Snack Foods              563
# Fruits and Vegetables    556
# Household                414
# Frozen Foods             334
# Canned                   294
# Dairy                    263
# Baking Goods             259
# Health and Hygiene       222
# Meat                     202
# Soft Drinks              193
# Breads                   115
# Hard Drinks               97
# Others                    82
# Starchy Foods             62
# Breakfast                 54
# Seafood                   32
# Name: Product_Type, dtype: int64

# %% [markdown]
# # One hot encodiing of of top 11 product type

# %%
# rdf= [x for x in df.Product_Type.value_counts().sort_values(ascending=False).head(11).index]
# for label in rdf:
#     df['Product_Type'+ label]=np.where(df['Product_Type']==label,1,0)
# for label in rdf:
#     df2['Product_Type'+ label]=np.where(df2['Product_Type']==label,1,0)

# %%
type_count= df['Product_Type'].value_counts().sort_values( ascending=False)
type_count
# grouped_11=df[['Product_Type','Product_Supermarket_Sales']]
# # grpd_11=grouped_11.groupby(['Product_Type'],as_index=False).sum()
# # grpd_11=grpd_11.sort_values(['Product_Supermarket_Sales'], ascending=False)
# # grpd_11
# Out:
# Snack Foods              563
# Fruits and Vegetables    556
# Household                414
# Frozen Foods             334
# Canned                   294
# Dairy                    263
# Baking Goods             259
# Health and Hygiene       222
# Meat                     202
# Soft Drinks              193
# Breads                   115
# Hard Drinks               97
# Others                    82
# Starchy Foods             62
# Breakfast                 54
# Seafood                   32
# Name: Product_Type, dtype: int64

# %%
type_count.index
# Out:
# Index(['Snack Foods', 'Fruits and Vegetables', 'Household', 'Frozen Foods',
#        'Canned', 'Dairy', 'Baking Goods', 'Health and Hygiene', 'Meat',
#        'Soft Drinks', 'Breads', 'Hard Drinks', 'Others', 'Starchy Foods',
#        'Breakfast', 'Seafood'],
#       dtype='object')

# %%
ptype_encode = {}
ptype_encode_values = range(16,0,-1)
for i,k in zip(type_count.index,ptype_encode_values):
    ptype_encode[i]=k
ptype_encode
# Out:
# {'Snack Foods': 16,
#  'Fruits and Vegetables': 15,
#  'Household': 14,
#  'Frozen Foods': 13,
#  'Canned': 12,
#  'Dairy': 11,
#  'Baking Goods': 10,
#  'Health and Hygiene': 9,
#  'Meat': 8,
#  'Soft Drinks': 7,
#  'Breads': 6,
#  'Hard Drinks': 5,
#  'Others': 4,
#  'Starchy Foods': 3,
#  'Breakfast': 2,
#  'Seafood': 1}

# %%
df['Product_Type'] = df['Product_Type'].map(ptype_encode)

# %%
df
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0                 DRB24            CHUKWUDI017              DRB24_CHUKWUDI017
# 1                 FDR31            CHUKWUDI019              FDR31_CHUKWUDI019
# 2                 FDP16            CHUKWUDI017              FDP16_CHUKWUDI017
# 3                 FDY16            CHUKWUDI027              FDY16_CHUKWUDI027
# 4                 FDY48            CHUKWUDI046              FDY48_CHUKWUDI046
# ...                 ...                    ...                            ...
# 3737              FDK10            CHUKWUDI017              FDK10_CHUKWUDI017
# 3738              DRC27            CHUKWUDI045              DRC27_CHUKWUDI045
# 3739              FDW57            CHUKWUDI046              FDW57_CHUKWUDI046
# 3740              NCF30            CHUKWUDI018              NCF30_CHUKWUDI018
# 3741              FDS49            CHUKWUDI013              FDS49_CHUKWUDI013
#
#       Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0              8.785                    3                  0.020694
# 1              6.460                    2                  0.086078
# 2             18.600                    3                  0.039517
# 3             18.350                    2                  0.091780
# 4             14.000                    3                  0.023735
# ...              ...                  ...                       ...
# 3737           5.785                    2                  0.040587
# 3738          13.800                    3                  0.058220
# 3739           8.310                    2                  0.000000
# 3740          17.000                    3                  0.126758
# 3741           9.000                    3                  0.079279
#
#       Product_Type  Product_Price  Supermarket_Opening_Year  \
# 0                7         382.91                      2014
# 1               15         359.53                      1992
# 2               13         609.20                      2014
# 3               13         456.32                      1992
# 4               10         258.08                      2004
# ...            ...            ...                       ...
# 3737            16         450.92                      2014
# 3738            11         618.70                      2009
# 3739            16         443.51                      2004
# 3740            14         311.34                      2016
# 3741            12         193.16                      1994
#
#       Supermarket _Size  Supermarket_Location_Type  Supermarket_Type  \
# 0                     3                          3                 3
# 1                     2                          1                 1
# 2                     3                          3                 3
# 3                     3                          2                 4
# 4                     2                          1                 3
# ...                 ...                        ...               ...
# 3737                  3                          3                 3
# 3738                  3                          3                 3
# 3739                  2                          1                 3
# 3740                  3                          2                 2
# 3741                  1                          2                 3
#
#       Product_Supermarket_Sales
# 0                       4633.97
# 1                        729.05
# 2                      14740.81
# 3                      16137.33
# 4                       4613.99
# ...                         ...
# 3737                    3145.91
# 3738                    3685.20
# 3739                    9740.65
# 3740                    2831.31
# 3741                    3338.99
#
# [3742 rows x 13 columns]

# %%
df2['Product_Type'] = df2['Product_Type'].map(ptype_encode)
df2
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0                 FDC15            CHUKWUDI049              FDC15_CHUKWUDI049
# 1                 NCY06            CHUKWUDI018              NCY06_CHUKWUDI018
# 2                 DRB24            CHUKWUDI035              DRB24_CHUKWUDI035
# 3                 NCG54            CHUKWUDI018              NCG54_CHUKWUDI018
# 4                 NCA42            CHUKWUDI017              NCA42_CHUKWUDI017
# ...                 ...                    ...                            ...
# 1243              FDW39            CHUKWUDI018              FDW39_CHUKWUDI018
# 1244              FDB40            CHUKWUDI018              FDB40_CHUKWUDI018
# 1245              FDX32            CHUKWUDI018              FDX32_CHUKWUDI018
# 1246              FDX37            CHUKWUDI049              FDX37_CHUKWUDI049
# 1247              FDZ35            CHUKWUDI049              FDZ35_CHUKWUDI049
#
#       Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0              8.785                    3                  0.178246
# 1              6.460                    3                  0.061434
# 2             18.600                    3                  0.020573
# 3             18.350                    3                  0.080131
# 4             14.000                    3                  0.028710
# ...              ...                  ...                       ...
# 1243           8.760                    2                  0.037061
# 1244           6.095                    2                  0.007571
# 1245          10.800                    2                  0.100265
# 1246          14.100                    3                  0.063127
# 1247          20.250                    2                  0.000000
#
#       Product_Type  Product_Price  Supermarket_Opening_Year  \
# 0               11         395.32                      2006
# 1               14         327.49                      2016
# 2                7         391.16                      2011
# 3               14         427.28                      2016
# 4               14         395.40                      2014
# ...            ...            ...                       ...
# 1243             8         442.09                      2016
# 1244            11         361.53                      2016
# 1245            15         356.45                      2016
# 1246            12         251.18                      2006
# 1247             6         254.25                      2006
#
#       Supermarket _Size  Supermarket_Location_Type  Supermarket_Type
# 0                     3                          1                 3
# 1                     3                          2                 2
# 2                     2                          3                 3
# 3                     3                          2                 2
# 4                     3                          3                 3
# ...                 ...                        ...               ...
# 1243                  3                          2                 2
# 1244                  3                          2                 2
# 1245                  3                          2                 2
# 1246                  3                          1                 3
# 1247                  3                          1                 3
#
# [1248 rows x 12 columns]

# %%
grouped_7=df[['Supermarket_Opening_Year','Supermarket_Identifier','Product_Supermarket_Sales']]
grpd_7=grouped_7.groupby(['Supermarket_Opening_Year','Supermarket_Identifier'],as_index=False).mean()
grpd_7.sort_values(['Product_Supermarket_Sales'], ascending=False)
# Out:
#    Supermarket_Opening_Year Supermarket_Identifier  Product_Supermarket_Sales
# 1                      1992            CHUKWUDI027               12541.373382
# 7                      2011            CHUKWUDI035                7907.270484
# 8                      2014            CHUKWUDI017                7468.619197
# 6                      2009            CHUKWUDI045                7398.398568
# 5                      2006            CHUKWUDI049                6352.267561
# 3                      2004            CHUKWUDI046                5753.361804
# 9                      2016            CHUKWUDI018                5588.015335
# 2                      1994            CHUKWUDI013                3998.670359
# 0                      1992            CHUKWUDI019                1064.223020
# 4                      2005            CHUKWUDI010                 606.450625

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="Supermarket_Opening_Year", y="Product_Supermarket_Sales", data=grpd_7)
plt.ylim(0,)
# Out:
# (0, 13143.191276880061)

# %%
grpd_7.corr()
# Out:
#                            Supermarket_Opening_Year  Product_Supermarket_Sales
# Supermarket_Opening_Year                   1.000000                   0.095753
# Product_Supermarket_Sales                  0.095753                   1.000000

# %%
df.corr()
# Out:
#                            Product_Weight  Product_Fat_Content  \
# Product_Weight                   1.000000             0.027850
# Product_Fat_Content              0.027850             1.000000
# Product_Shelf_Visibility        -0.015260            -0.055591
# Product_Type                     0.063841            -0.026270
# Product_Price                    0.037564            -0.000825
# Supermarket_Opening_Year         0.000649            -0.005549
# Supermarket _Size                0.000428             0.004177
# Supermarket_Location_Type       -0.005736            -0.000871
# Supermarket_Type                -0.002608             0.022995
# Product_Supermarket_Sales        0.015314            -0.005365
#
#                            Product_Shelf_Visibility  Product_Type  \
# Product_Weight                            -0.015260      0.063841
# Product_Fat_Content                       -0.055591     -0.026270
# Product_Shelf_Visibility                   1.000000     -0.004341
# Product_Type                              -0.004341      1.000000
# Product_Price                             -0.028941      0.021038
# Supermarket_Opening_Year                  -0.084218      0.009036
# Supermarket _Size                          0.014576      0.005978
# Supermarket_Location_Type                 -0.086771      0.011903
# Supermarket_Type                          -0.272450      0.017004
# Product_Supermarket_Sales                 -0.161008      0.028915
#
#                            Product_Price  Supermarket_Opening_Year  \
# Product_Weight                  0.037564                  0.000649
# Product_Fat_Content            -0.000825                 -0.005549
# Product_Shelf_Visibility       -0.028941                 -0.084218
# Product_Type                    0.021038                  0.009036
# Product_Price                   1.000000                  0.161113
# Supermarket_Opening_Year        0.161113                  1.000000
# Supermarket _Size               0.313759                  0.501893
# Supermarket_Location_Type       0.255820                  0.459908
# Supermarket_Type                0.207156                 -0.080103
# Product_Supermarket_Sales       0.524002                  0.057508
#
#                            Supermarket _Size  Supermarket_Location_Type  \
# Product_Weight                      0.000428                  -0.005736
# Product_Fat_Content                 0.004177                  -0.000871
# Product_Shelf_Visibility            0.014576                  -0.086771
# Product_Type                        0.005978                   0.011903
# Product_Price                       0.313759                   0.255820
# Supermarket_Opening_Year            0.501893                   0.459908
# Supermarket _Size                   1.000000                   0.161019
# Supermarket_Location_Type           0.161019                   1.000000
# Supermarket_Type                   -0.022944                   0.224456
# Product_Supermarket_Sales           0.225555                   0.236921
#
#                            Supermarket_Type  Product_Supermarket_Sales
# Product_Weight                    -0.002608                   0.015314
# Product_Fat_Content                0.022995                  -0.005365
# Product_Shelf_Visibility          -0.272450                  -0.161008
# Product_Type                       0.017004                   0.028915
# Product_Price                      0.207156                   0.524002
# Supermarket_Opening_Year          -0.080103                   0.057508
# Supermarket _Size                 -0.022944                   0.225555
# Supermarket_Location_Type          0.224456                   0.236921
# Supermarket_Type                   1.000000                   0.591609
# Product_Supermarket_Sales          0.591609                   1.000000

# %% [markdown]
# NOT DONE WITH FEATURE ENGINEERING

# %%
df.columns
# Out:
# Index(['Product_Identifier', 'Supermarket_Identifier',
#        'Product_Supermarket_Identifier', 'Product_Weight',
#        'Product_Fat_Content', 'Product_Shelf_Visibility', 'Product_Type',
#        'Product_Price', 'Supermarket_Opening_Year', 'Supermarket _Size',
#        'Supermarket_Location_Type', 'Supermarket_Type',
#        'Product_Supermarket_Sales'],
#       dtype='object')

# %%
# df.head()

# %%
# df2.head()

# %% [markdown]
# # Normalization

# %%
# No need for normalizing for this the Tree based algos though

# df['Product_Price']=df['Product_Price']/df['Product_Price'].max()
# df2['Product_Price']=df2['Product_Price']/df2['Product_Price'].max()

# df['Product_Weight']=df['Product_Weight']/df['Product_Weight'].max()
# df2['Product_Weight']=df2['Product_Weight']/df2['Product_Weight'].max()
# df.head()

# %% [markdown]
# # Assigning Dependent and Independent Variables

# %%
X=df.drop(['Product_Identifier','Supermarket_Identifier','Product_Supermarket_Identifier','Product_Type','Product_Weight',
           'Supermarket_Opening_Year','Product_Fat_Content','Product_Supermarket_Sales'], axis=1)

# %%
X.head()
# Out:
#    Product_Shelf_Visibility  Product_Price  Supermarket _Size  \
# 0                  0.020694         382.91                  3
# 1                  0.086078         359.53                  2
# 2                  0.039517         609.20                  3
# 3                  0.091780         456.32                  3
# 4                  0.023735         258.08                  2
#
#    Supermarket_Location_Type  Supermarket_Type
# 0                          3                 3
# 1                          1                 1
# 2                          3                 3
# 3                          2                 4
# 4                          1                 3

# %%
y=df.Product_Supermarket_Sales
y.head()
# Out:
# 0     4633.97
# 1      729.05
# 2    14740.81
# 3    16137.33
# 4     4613.99
# Name: Product_Supermarket_Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# # GradientBoostingRegression Algo

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# %%
params = {'n_estimators': 500,
          'max_depth': 4,
          'min_samples_split': 5,
          'learning_rate': 0.01,
          'loss': 'ls'}

# %%
reg = GradientBoostingRegressor()#**params)
reg.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
mse = mean_squared_error(y_train, reg.predict(X_train))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
print(reg.score(X_train,y_train))
# Out:
# The mean squared error (MSE) on test set: 6978052.7162
# 0.6399340589860796

# %%
mse = mean_squared_error(y_test, reg.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
print(reg.score(X_test,y_test))
# Out:
# The mean squared error (MSE) on test set: 9294110.1168
# 0.5692804059471956

# %% [markdown]
# # predicting the test data

# %%
# X2=df2.drop(['Product_Identifier','Supermarket_Identifier','Product_Supermarket_Identifier','Product_Fat_Content','Supermarket_Opening_Year'], axis=1)
# X2=pd.get_dummies(X2)
# X2.head()

# %%
# test_pred = reg.predict(X2) #predict on the test set for submission
# df3= {'Product_Supermarket_Identifier': df2['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales': test_pred}
# sub = pd.DataFrame(data=df3)
# sub = sub[['Product_Supermarket_Identifier', 'Product_Supermarket_Sales']]

# %%
# sub.shape

# %%
# # sub.to_csv('submission.csv', index = False)

# %%
# subxamp=pd.read_csv('sample_submission.csv')
# subxamp.head()

# %% [markdown]
# # XGBRFRegressor Algo

# %%
from xgboost import XGBRFRegressor

# %%
clf = XGBRFRegressor()#random_state = 1,reg_alpha=1,n_estimators=100 ,learning_rate=1)#**params)
clf.fit(X_train, y_train)
# Out:
# XGBRFRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=0.8, colsample_bytree=1, gamma=0, gpu_id=-1,
#                importance_type='gain', interaction_constraints='',
#                learning_rate=1, max_delta_step=0, max_depth=6,
#                min_child_weight=1, missing=nan, monotone_constraints='()',
#                n_estimators=100, n_jobs=0, num_parallel_tree=100,
#                objective='reg:squarederror', random_state=0, reg_alpha=0,
#                reg_lambda=1e-05, scale_pos_weight=1, subsample=0.8,
#                tree_method='exact', validate_parameters=1, verbosity=None)

# %%
mse = mean_squared_error(y_train, clf.predict(X_train))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
print(clf.score(X_train,y_train))
# Out:
# The mean squared error (MSE) on test set: 7481524.2777
# 0.6139550403501894

# %%
mse = mean_squared_error(y_test, clf.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
print(clf.score(X_test,y_test))
# Out:
# The mean squared error (MSE) on test set: 9180936.6113
# 0.5745252379717908

# %% [markdown]
# # XGBRegressor Algo

# %%
from xgboost import XGBRegressor
parame = {"n_jobs":-1,'n_estimators':127,'learning_rate':0.08,
                    'max_depth':3,'subsample':0.9,'random_state':1,
                    'colsample_bylevel':0.9,'min_child_weight':2,
                    'reg_alpha':1
        }
# n_jobs=-1,n_estimators=127,learning_rate=0.08,
#                     max_depth=3,subsample=0.9,random_state =1,
#                     colsample_bylevel=0.9,min_child_weight=2,
#                     reg_alpha=1

# clf1 = XGBRegressor(n_estimators=64,learning_rate=0.08,max_depth=4,
#                      subsample=0.7, min_child_weight=2,reg_alpha=1)#**parame)

clf1 = XGBRegressor()
clf1.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
#very latest best
# clf1 = XGBRegressor(n_estimators=62,learning_rate=0.07,max_depth=5,
#                       subsample=0.7, min_child_weight=2,reg_alpha=1)
# clf1.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.07, max_delta_step=0, max_depth=5,
#              min_child_weight=2, missing=nan, monotone_constraints='()',
#              n_estimators=62, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=1,
#              reg_lambda=1, scale_pos_weight=1, subsample=0.7,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
clf1 = XGBRegressor(n_estimators=62,learning_rate=0.07,max_depth=5,
                      subsample=0.7, min_child_weight=2,reg_alpha=0.8)
clf1.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.07, max_delta_step=0, max_depth=5,
#              min_child_weight=2, missing=nan, monotone_constraints='()',
#              n_estimators=62, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0.8,
#              reg_lambda=1, scale_pos_weight=1, subsample=0.7,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
mse = mean_squared_error(y_train, clf1.predict(X_train))
print("The mean squared error (MSE) on train set: {:.4f}".format(mse))
print(clf1.score(X_train,y_train))
# Out:
# The mean squared error (MSE) on train set: 6709120.3805
# 0.6538109066513328

# %%
mse = mean_squared_error(y_test, clf1.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
print(clf1.score(X_test,y_test))
# Out:
# The mean squared error (MSE) on test set: 9125586.7604
# 0.5770903318864908

# %% [markdown]
# # catBOOST

# %%
from catboost import CatBoostRegressor

# %%
# model = CatBoostRegressor()
#     parameters = {'depth'         : [6,8,10],
#                   'learning_rate' : [0.01, 0.05, 0.1],
#                   'iterations'    : [30, 50, 100]
#                  }
#     grid = GridSearchCV(estimator=model, param_grid = parameters, cv = 2, n_jobs=-1)
#     grid.fit(X_train, y_train)

#     # Results from Grid Search
#     print("\n========================================================")
#     print(" Results from Grid Search " )
#     print("========================================================")
#     print("\n The best estimator across ALL searched params:\n",
#           grid.best_estimator_)
#     print("\n The best score across ALL searched params:\n",
#           grid.best_score_)
#     print("\n The best parameters across ALL searched params:\n",
#           grid.best_params_)
#     print("\n ====================

# %%
ctb = CatBoostRegressor()
ctb.fit(X_train,y_train)
# Out:
# Learning rate set to 0.04744
# 0:	learn: 4293.6030577	total: 118ms	remaining: 1m 57s
# 1:	learn: 4196.0507670	total: 121ms	remaining: 1m
# 2:	learn: 4100.4411476	total: 126ms	remaining: 42s
# 3:	learn: 4013.7487427	total: 131ms	remaining: 32.7s
# 4:	learn: 3927.6809739	total: 138ms	remaining: 27.5s
# 5:	learn: 3849.7222606	total: 148ms	remaining: 24.5s
# 6:	learn: 3776.6698143	total: 153ms	remaining: 21.6s
# 7:	learn: 3708.8691957	total: 162ms	remaining: 20.1s
# 8:	learn: 3646.2695982	total: 182ms	remaining: 20.1s
# 9:	learn: 3586.6090442	total: 187ms	remaining: 18.5s
# 10:	learn: 3532.3476982	total: 199ms	remaining: 17.9s
# 11:	learn: 3484.1126567	total: 203ms	remaining: 16.7s
# 12:	learn: 3437.2144606	total: 215ms	remaining: 16.4s
# 13:	learn: 3392.3840788	total: 222ms	remaining: 15.6s
# 14:	learn: 3353.0300418	total: 226ms	remaining: 14.8s
# 15:	learn: 3315.2323662	total: 230ms	remaining: 14.1s
# 16:	learn: 3280.0395254	total: 235ms	remaining: 13.6s
# 17:	learn: 3248.3788807	total: 240ms	remaining: 13.1s
# 18:	learn: 3217.3774331	total: 244ms	remaining: 12.6s
# 19:	learn: 3190.1438341	total: 250ms	remaining: 12.2s
# 20:	learn: 3163.8820649	total: 259ms	remaining: 12.1s
# 21:	learn: 3139.6395846	total: 263ms	remaining: 11.7s
# 22:	learn: 3119.2919015	total: 267ms	remaining: 11.3s
# 23:	learn: 3101.4717982	total: 271ms	remaining: 11s
# 24:	learn: 3085.1434343	total: 274ms	remaining: 10.7s
# 25:	learn: 3068.9657708	total: 279ms	remaining: 10.5s
# 26:	learn: 3051.8307962	total: 284ms	remaining: 10.2s
# 27:	learn: 3036.8006098	total: 290ms	remaining: 10.1s
# 28:	learn: 3022.2497908	total: 294ms	remaining: 9.86s
# 29:	learn: 3011.4137684	total: 303ms	remaining: 9.81s
# 30:	learn: 3001.1649489	total: 311ms	remaining: 9.72s
# 31:	learn: 2992.4417788	total: 336ms	remaining: 10.2s
# 32:	learn: 2984.0303729	total: 343ms	remaining: 10s
# 33:	learn: 2974.1155476	total: 349ms	remaining: 9.92s
# 34:	learn: 2967.2639720	total: 366ms	remaining: 10.1s
# 35:	learn: 2959.7006528	total: 371ms	remaining: 9.93s
# 36:	learn: 2952.7672373	total: 374ms	remaining: 9.74s
# 37:	learn: 2945.6533171	total: 379ms	remaining: 9.61s
# 38:	learn: 2940.1331740	total: 385ms	remaining: 9.48s
# 39:	learn: 2934.6513462	total: 394ms	remaining: 9.46s
# 40:	learn: 2928.7792892	total: 405ms	remaining: 9.47s
# 41:	learn: 2923.4385496	total: 410ms	remaining: 9.36s
# 42:	learn: 2918.3045398	total: 416ms	remaining: 9.26s
# 43:	learn: 2912.9405245	total: 422ms	remaining: 9.17s
# 44:	learn: 2910.6209502	total: 424ms	remaining: 9.01s
# 45:	learn: 2907.0560183	total: 429ms	remaining: 8.91s
# 46:	learn: 2903.3931448	total: 434ms	remaining: 8.8s
# 47:	learn: 2900.1968952	total: 438ms	remaining: 8.69s
# 48:	learn: 2897.2436714	total: 443ms	remaining: 8.59s
# 49:	learn: 2894.4531091	total: 446ms	remaining: 8.47s
# 50:	learn: 2891.6839099	total: 450ms	remaining: 8.38s
# 51:	learn: 2888.7900360	total: 455ms	remaining: 8.29s
# 52:	learn: 2885.6859900	total: 461ms	remaining: 8.23s
# 53:	learn: 2882.8457898	total: 467ms	remaining: 8.17s
# 54:	learn: 2880.1281118	total: 474ms	remaining: 8.14s
# 55:	learn: 2876.7685319	total: 499ms	remaining: 8.41s
# 56:	learn: 2873.9849204	total: 503ms	remaining: 8.32s
# 57:	learn: 2872.2349672	total: 554ms	remaining: 9s
# 58:	learn: 2869.8095569	total: 563ms	remaining: 8.97s
# 59:	learn: 2868.0510647	total: 573ms	remaining: 8.98s
# 60:	learn: 2865.6929495	total: 582ms	remaining: 8.96s
# 61:	learn: 2863.3489934	total: 589ms	remaining: 8.9s
# 62:	learn: 2861.4591678	total: 602ms	remaining: 8.95s
# 63:	learn: 2860.0830520	total: 607ms	remaining: 8.88s
# 64:	learn: 2858.5732811	total: 613ms	remaining: 8.82s
# 65:	learn: 2856.8088372	total: 660ms	remaining: 9.33s
# 66:	learn: 2854.4387335	total: 668ms	remaining: 9.29s
# 67:	learn: 2852.6026112	total: 676ms	remaining: 9.26s
# 68:	learn: 2852.1938882	total: 679ms	remaining: 9.16s
# 69:	learn: 2850.9280699	total: 687ms	remaining: 9.12s
# 70:	learn: 2850.1342307	total: 690ms	remaining: 9.03s
# 71:	learn: 2848.8165372	total: 695ms	remaining: 8.95s
# 72:	learn: 2847.3956928	total: 703ms	remaining: 8.93s
# 73:	learn: 2846.5492194	total: 711ms	remaining: 8.89s
# 74:	learn: 2845.2262093	total: 720ms	remaining: 8.88s
# 75:	learn: 2843.3472207	total: 743ms	remaining: 9.04s
# 76:	learn: 2841.4667936	total: 749ms	remaining: 8.97s
# 77:	learn: 2840.1631408	total: 754ms	remaining: 8.92s
# 78:	learn: 2839.5152029	total: 774ms	remaining: 9.03s
# 79:	learn: 2838.5162046	total: 779ms	remaining: 8.96s
# 80:	learn: 2837.9576894	total: 785ms	remaining: 8.9s
# 81:	learn: 2836.6679157	total: 789ms	remaining: 8.83s
# 82:	learn: 2834.9270266	total: 793ms	remaining: 8.76s
# 83:	learn: 2834.4781618	total: 799ms	remaining: 8.71s
# 84:	learn: 2833.5958467	total: 804ms	remaining: 8.66s
# 85:	learn: 2832.6247596	total: 809ms	remaining: 8.6s
# 86:	learn: 2832.4187445	total: 812ms	remaining: 8.52s
# 87:	learn: 2831.0138451	total: 854ms	remaining: 8.85s
# 88:	learn: 2830.4479149	total: 877ms	remaining: 8.97s
# 89:	learn: 2830.2500966	total: 882ms	remaining: 8.92s
# 90:	learn: 2829.2532815	total: 891ms	remaining: 8.9s
# 91:	learn: 2828.6385631	total: 904ms	remaining: 8.92s
# 92:	learn: 2827.3771265	total: 908ms	remaining: 8.86s
# 93:	learn: 2826.4175161	total: 912ms	remaining: 8.79s
# 94:	learn: 2825.1429906	total: 918ms	remaining: 8.74s
# 95:	learn: 2823.7265547	total: 922ms	remaining: 8.68s
# 96:	learn: 2822.6693828	total: 928ms	remaining: 8.64s
# 97:	learn: 2821.0664508	total: 948ms	remaining: 8.73s
# 98:	learn: 2820.3986054	total: 957ms	remaining: 8.71s
# 99:	learn: 2820.1077869	total: 964ms	remaining: 8.67s
# 100:	learn: 2819.6821848	total: 967ms	remaining: 8.61s
# 101:	learn: 2818.9517035	total: 971ms	remaining: 8.55s
# 102:	learn: 2817.8958479	total: 977ms	remaining: 8.51s
# 103:	learn: 2817.2704772	total: 985ms	remaining: 8.49s
# 104:	learn: 2816.4301972	total: 991ms	remaining: 8.45s
# 105:	learn: 2816.1506021	total: 996ms	remaining: 8.4s
# 106:	learn: 2815.7952425	total: 1s	remaining: 8.37s
# 107:	learn: 2814.8936925	total: 1.01s	remaining: 8.34s
# 108:	learn: 2812.8804054	total: 1.02s	remaining: 8.31s
# 109:	learn: 2811.2404589	total: 1.02s	remaining: 8.28s
# 110:	learn: 2810.3012689	total: 1.03s	remaining: 8.26s
# 111:	learn: 2809.1208048	total: 1.04s	remaining: 8.24s
# 112:	learn: 2807.4676798	total: 1.04s	remaining: 8.2s
# 113:	learn: 2806.6398273	total: 1.05s	remaining: 8.15s
# 114:	learn: 2806.1548770	total: 1.05s	remaining: 8.12s
# 115:	learn: 2805.8075225	total: 1.09s	remaining: 8.3s
# 116:	learn: 2804.8651234	total: 1.09s	remaining: 8.25s
# 117:	learn: 2804.8646675	total: 1.09s	remaining: 8.19s
# 118:	learn: 2802.6041646	total: 1.1s	remaining: 8.17s
# 119:	learn: 2801.7707406	total: 1.11s	remaining: 8.14s
# 120:	learn: 2800.7902018	total: 1.12s	remaining: 8.13s
# 121:	learn: 2800.0857925	total: 1.13s	remaining: 8.12s
# 122:	learn: 2799.1214905	total: 1.13s	remaining: 8.08s
# 123:	learn: 2798.9422723	total: 1.14s	remaining: 8.04s
# 124:	learn: 2797.9548835	total: 1.14s	remaining: 8.01s
# 125:	learn: 2797.2206245	total: 1.15s	remaining: 7.97s
# 126:	learn: 2796.4904847	total: 1.15s	remaining: 7.92s
# 127:	learn: 2795.4830560	total: 1.16s	remaining: 7.9s
# 128:	learn: 2795.3650356	total: 1.16s	remaining: 7.87s
# 129:	learn: 2794.3923548	total: 1.17s	remaining: 7.84s
# 130:	learn: 2794.0541000	total: 1.18s	remaining: 7.8s
# 131:	learn: 2793.1272482	total: 1.18s	remaining: 7.76s
# 132:	learn: 2791.9972340	total: 1.19s	remaining: 7.73s
# 133:	learn: 2791.8894301	total: 1.19s	remaining: 7.68s
# 134:	learn: 2791.6963357	total: 1.19s	remaining: 7.63s
# 135:	learn: 2790.4179011	total: 1.2s	remaining: 7.59s
# 136:	learn: 2790.0926412	total: 1.2s	remaining: 7.58s
# 137:	learn: 2789.2452175	total: 1.21s	remaining: 7.56s
# 138:	learn: 2788.4744078	total: 1.21s	remaining: 7.52s
# 139:	learn: 2788.1441915	total: 1.22s	remaining: 7.51s
# 140:	learn: 2787.4688789	total: 1.23s	remaining: 7.48s
# 141:	learn: 2787.3742958	total: 1.23s	remaining: 7.45s
# 142:	learn: 2786.7048134	total: 1.24s	remaining: 7.41s
# 143:	learn: 2786.0368416	total: 1.24s	remaining: 7.38s
# 144:	learn: 2784.2808169	total: 1.25s	remaining: 7.34s
# 145:	learn: 2783.5762723	total: 1.25s	remaining: 7.31s
# 146:	learn: 2783.0229888	total: 1.26s	remaining: 7.3s
# 147:	learn: 2781.6712751	total: 1.27s	remaining: 7.32s
# 148:	learn: 2780.6787101	total: 1.28s	remaining: 7.3s
# 149:	learn: 2779.7985302	total: 1.28s	remaining: 7.27s
# 150:	learn: 2778.8202861	total: 1.29s	remaining: 7.25s
# 151:	learn: 2777.3254366	total: 1.3s	remaining: 7.23s
# 152:	learn: 2775.9804503	total: 1.3s	remaining: 7.21s
# 153:	learn: 2775.1753539	total: 1.31s	remaining: 7.2s
# 154:	learn: 2773.7210384	total: 1.32s	remaining: 7.18s
# 155:	learn: 2773.5591244	total: 1.32s	remaining: 7.14s
# 156:	learn: 2772.6062166	total: 1.32s	remaining: 7.11s
# 157:	learn: 2772.0011005	total: 1.33s	remaining: 7.08s
# 158:	learn: 2771.3378118	total: 1.33s	remaining: 7.05s
# 159:	learn: 2770.9940637	total: 1.34s	remaining: 7.03s
# 160:	learn: 2770.0212192	total: 1.34s	remaining: 7s
# 161:	learn: 2768.9316735	total: 1.35s	remaining: 6.99s
# 162:	learn: 2768.2425252	total: 1.36s	remaining: 6.97s
# 163:	learn: 2767.0259916	total: 1.36s	remaining: 6.95s
# 164:	learn: 2765.8029551	total: 1.37s	remaining: 6.92s
# 165:	learn: 2764.7504293	total: 1.37s	remaining: 6.91s
# 166:	learn: 2764.3738490	total: 1.38s	remaining: 6.88s
# 167:	learn: 2762.3887443	total: 1.38s	remaining: 6.85s
# 168:	learn: 2761.5523717	total: 1.39s	remaining: 6.83s
# 169:	learn: 2760.9441424	total: 1.4s	remaining: 6.82s
# 170:	learn: 2759.5243723	total: 1.4s	remaining: 6.8s
# 171:	learn: 2759.1109397	total: 1.41s	remaining: 6.77s
# 172:	learn: 2758.1337094	total: 1.41s	remaining: 6.75s
# 173:	learn: 2756.7065931	total: 1.42s	remaining: 6.72s
# 174:	learn: 2755.8871578	total: 1.42s	remaining: 6.7s
# 175:	learn: 2755.3329212	total: 1.43s	remaining: 6.67s
# 176:	learn: 2754.1521569	total: 1.47s	remaining: 6.86s
# 177:	learn: 2752.3207120	total: 1.48s	remaining: 6.83s
# 178:	learn: 2750.8477260	total: 1.49s	remaining: 6.82s
# 179:	learn: 2749.6637396	total: 1.49s	remaining: 6.8s
# 180:	learn: 2747.9823085	total: 1.5s	remaining: 6.8s
# 181:	learn: 2747.5191591	total: 1.51s	remaining: 6.78s
# 182:	learn: 2745.5032246	total: 1.52s	remaining: 6.8s
# 183:	learn: 2744.4645448	total: 1.53s	remaining: 6.8s
# 184:	learn: 2743.3955868	total: 1.54s	remaining: 6.77s
# 185:	learn: 2742.5976391	total: 1.54s	remaining: 6.74s
# 186:	learn: 2741.5746875	total: 1.54s	remaining: 6.72s
# 187:	learn: 2740.3610803	total: 1.55s	remaining: 6.7s
# 188:	learn: 2739.6240940	total: 1.55s	remaining: 6.67s
# 189:	learn: 2738.9649669	total: 1.57s	remaining: 6.71s
# 190:	learn: 2738.3428192	total: 1.58s	remaining: 6.7s
# 191:	learn: 2736.7747946	total: 1.59s	remaining: 6.7s
# 192:	learn: 2735.3883393	total: 1.6s	remaining: 6.68s
# 193:	learn: 2734.4260760	total: 1.61s	remaining: 6.7s
# 194:	learn: 2733.6263024	total: 1.62s	remaining: 6.68s
# 195:	learn: 2733.1690411	total: 1.62s	remaining: 6.66s
# 196:	learn: 2731.2639224	total: 1.63s	remaining: 6.64s
# 197:	learn: 2729.9507981	total: 1.63s	remaining: 6.61s
# 198:	learn: 2728.8957182	total: 1.64s	remaining: 6.59s
# 199:	learn: 2727.6050576	total: 1.64s	remaining: 6.57s
# 200:	learn: 2727.0906039	total: 1.65s	remaining: 6.55s
# 201:	learn: 2725.4572255	total: 1.65s	remaining: 6.53s
# 202:	learn: 2723.8962391	total: 1.66s	remaining: 6.51s
# 203:	learn: 2722.0423910	total: 1.66s	remaining: 6.48s
# 204:	learn: 2721.5609492	total: 1.67s	remaining: 6.47s
# 205:	learn: 2719.9037947	total: 1.68s	remaining: 6.47s
# 206:	learn: 2718.3950064	total: 1.74s	remaining: 6.68s
# 207:	learn: 2717.6731834	total: 1.75s	remaining: 6.66s
# 208:	learn: 2716.8805936	total: 1.75s	remaining: 6.63s
# 209:	learn: 2715.8282694	total: 1.76s	remaining: 6.61s
# 210:	learn: 2714.9621889	total: 1.76s	remaining: 6.59s
# 211:	learn: 2713.6629657	total: 1.77s	remaining: 6.57s
# 212:	learn: 2713.2362755	total: 1.78s	remaining: 6.57s
# 213:	learn: 2711.7824660	total: 1.78s	remaining: 6.55s
# 214:	learn: 2710.5694597	total: 1.79s	remaining: 6.54s
# 215:	learn: 2708.8065908	total: 1.8s	remaining: 6.52s
# 216:	learn: 2708.3011071	total: 1.8s	remaining: 6.5s
# 217:	learn: 2707.0069783	total: 1.81s	remaining: 6.5s
# 218:	learn: 2706.0935805	total: 1.82s	remaining: 6.48s
# 219:	learn: 2705.2525472	total: 1.82s	remaining: 6.47s
# 220:	learn: 2704.4398990	total: 1.83s	remaining: 6.46s
# 221:	learn: 2703.2624776	total: 1.83s	remaining: 6.43s
# 222:	learn: 2702.0876072	total: 1.84s	remaining: 6.41s
# 223:	learn: 2700.3359586	total: 1.85s	remaining: 6.41s
# 224:	learn: 2699.1347097	total: 1.85s	remaining: 6.38s
# 225:	learn: 2698.3494900	total: 1.86s	remaining: 6.37s
# 226:	learn: 2697.2539695	total: 1.87s	remaining: 6.36s
# 227:	learn: 2695.8624423	total: 1.87s	remaining: 6.33s
# 228:	learn: 2694.5620910	total: 1.87s	remaining: 6.31s
# 229:	learn: 2692.5533267	total: 1.88s	remaining: 6.29s
# 230:	learn: 2691.8592902	total: 1.88s	remaining: 6.27s
# 231:	learn: 2691.0771327	total: 1.89s	remaining: 6.25s
# 232:	learn: 2690.1541320	total: 1.89s	remaining: 6.23s
# 233:	learn: 2689.4049047	total: 1.9s	remaining: 6.23s
# 234:	learn: 2688.4535014	total: 1.91s	remaining: 6.21s
# 235:	learn: 2686.8819203	total: 1.91s	remaining: 6.19s
# 236:	learn: 2685.4644335	total: 1.92s	remaining: 6.17s
# 237:	learn: 2684.2236492	total: 1.92s	remaining: 6.16s
# 238:	learn: 2682.9548557	total: 1.93s	remaining: 6.14s
# 239:	learn: 2682.3472598	total: 1.94s	remaining: 6.14s
# 240:	learn: 2681.4783032	total: 1.94s	remaining: 6.12s
# 241:	learn: 2680.4322782	total: 1.95s	remaining: 6.11s
# 242:	learn: 2678.9729771	total: 1.99s	remaining: 6.21s
# 243:	learn: 2678.2451401	total: 2.01s	remaining: 6.24s
# 244:	learn: 2677.0926947	total: 2.02s	remaining: 6.23s
# 245:	learn: 2676.0466453	total: 2.03s	remaining: 6.22s
# 246:	learn: 2674.8087235	total: 2.04s	remaining: 6.2s
# 247:	learn: 2674.3631218	total: 2.04s	remaining: 6.19s
# 248:	learn: 2673.2833175	total: 2.05s	remaining: 6.18s
# 249:	learn: 2671.9160437	total: 2.06s	remaining: 6.17s
# 250:	learn: 2671.1364022	total: 2.06s	remaining: 6.15s
# 251:	learn: 2669.4861461	total: 2.07s	remaining: 6.14s
# 252:	learn: 2668.7395144	total: 2.07s	remaining: 6.12s
# 253:	learn: 2667.2010399	total: 2.08s	remaining: 6.1s
# 254:	learn: 2666.3085549	total: 2.08s	remaining: 6.09s
# 255:	learn: 2665.1467957	total: 2.09s	remaining: 6.08s
# 256:	learn: 2664.1754603	total: 2.1s	remaining: 6.06s
# 257:	learn: 2663.5760222	total: 2.1s	remaining: 6.04s
# 258:	learn: 2662.9565946	total: 2.11s	remaining: 6.03s
# 259:	learn: 2662.3245829	total: 2.11s	remaining: 6.01s
# 260:	learn: 2661.1296250	total: 2.12s	remaining: 6s
# 261:	learn: 2659.9971430	total: 2.12s	remaining: 5.98s
# 262:	learn: 2659.3533967	total: 2.13s	remaining: 5.96s
# 263:	learn: 2658.2804813	total: 2.13s	remaining: 5.94s
# 264:	learn: 2657.3690495	total: 2.14s	remaining: 5.93s
# 265:	learn: 2656.1801188	total: 2.18s	remaining: 6.01s
# 266:	learn: 2655.2343181	total: 2.19s	remaining: 6s
# 267:	learn: 2653.7714545	total: 2.19s	remaining: 5.98s
# 268:	learn: 2652.6319770	total: 2.19s	remaining: 5.96s
# 269:	learn: 2651.6463765	total: 2.2s	remaining: 5.96s
# 270:	learn: 2650.6452503	total: 2.22s	remaining: 5.96s
# 271:	learn: 2649.9526534	total: 2.22s	remaining: 5.94s
# 272:	learn: 2648.6937417	total: 2.23s	remaining: 5.92s
# 273:	learn: 2648.4168402	total: 2.23s	remaining: 5.91s
# 274:	learn: 2647.4699767	total: 2.23s	remaining: 5.89s
# 275:	learn: 2646.8741914	total: 2.24s	remaining: 5.88s
# 276:	learn: 2645.8320099	total: 2.25s	remaining: 5.86s
# 277:	learn: 2645.4160009	total: 2.25s	remaining: 5.84s
# 278:	learn: 2644.2400798	total: 2.25s	remaining: 5.83s
# 279:	learn: 2643.2178604	total: 2.26s	remaining: 5.81s
# 280:	learn: 2642.1156214	total: 2.26s	remaining: 5.79s
# 281:	learn: 2641.7296208	total: 2.27s	remaining: 5.77s
# 282:	learn: 2641.0319526	total: 2.27s	remaining: 5.76s
# 283:	learn: 2640.2474805	total: 2.28s	remaining: 5.75s
# 284:	learn: 2639.3696713	total: 2.29s	remaining: 5.73s
# 285:	learn: 2638.6482613	total: 2.29s	remaining: 5.71s
# 286:	learn: 2637.7205106	total: 2.29s	remaining: 5.7s
# 287:	learn: 2636.5273718	total: 2.3s	remaining: 5.69s
# 288:	learn: 2635.5062266	total: 2.31s	remaining: 5.67s
# 289:	learn: 2634.5598829	total: 2.31s	remaining: 5.66s
# 290:	learn: 2633.5872281	total: 2.31s	remaining: 5.64s
# 291:	learn: 2633.1397855	total: 2.32s	remaining: 5.62s
# 292:	learn: 2632.1588344	total: 2.32s	remaining: 5.6s
# 293:	learn: 2631.6188353	total: 2.33s	remaining: 5.59s
# 294:	learn: 2630.6732373	total: 2.33s	remaining: 5.57s
# 295:	learn: 2629.8024120	total: 2.34s	remaining: 5.56s
# 296:	learn: 2628.4634495	total: 2.34s	remaining: 5.55s
# 297:	learn: 2627.8612597	total: 2.35s	remaining: 5.54s
# 298:	learn: 2626.7253137	total: 2.36s	remaining: 5.53s
# 299:	learn: 2625.0920528	total: 2.36s	remaining: 5.52s
# 300:	learn: 2624.2954090	total: 2.37s	remaining: 5.5s
# 301:	learn: 2622.4817824	total: 2.38s	remaining: 5.49s
# 302:	learn: 2621.7839443	total: 2.38s	remaining: 5.49s
# 303:	learn: 2620.5537446	total: 2.39s	remaining: 5.47s
# 304:	learn: 2619.6036771	total: 2.39s	remaining: 5.45s
# 305:	learn: 2618.6392211	total: 2.4s	remaining: 5.44s
# 306:	learn: 2617.8994766	total: 2.4s	remaining: 5.42s
# 307:	learn: 2617.2404259	total: 2.41s	remaining: 5.41s
# 308:	learn: 2616.1367470	total: 2.41s	remaining: 5.39s
# 309:	learn: 2614.5017926	total: 2.42s	remaining: 5.38s
# 310:	learn: 2613.5002937	total: 2.42s	remaining: 5.36s
# 311:	learn: 2612.9624668	total: 2.42s	remaining: 5.35s
# 312:	learn: 2612.0936958	total: 2.43s	remaining: 5.33s
# 313:	learn: 2611.1439911	total: 2.43s	remaining: 5.32s
# 314:	learn: 2610.5334163	total: 2.44s	remaining: 5.3s
# 315:	learn: 2609.2188809	total: 2.44s	remaining: 5.29s
# 316:	learn: 2608.3660701	total: 2.46s	remaining: 5.29s
# 317:	learn: 2607.9930333	total: 2.46s	remaining: 5.28s
# 318:	learn: 2606.5500552	total: 2.47s	remaining: 5.27s
# 319:	learn: 2605.7224368	total: 2.48s	remaining: 5.26s
# 320:	learn: 2605.1698759	total: 2.48s	remaining: 5.25s
# 321:	learn: 2604.3167302	total: 2.48s	remaining: 5.23s
# 322:	learn: 2603.2305804	total: 2.55s	remaining: 5.34s
# 323:	learn: 2602.5659570	total: 2.55s	remaining: 5.33s
# 324:	learn: 2601.6606226	total: 2.56s	remaining: 5.31s
# 325:	learn: 2601.3671554	total: 2.56s	remaining: 5.3s
# 326:	learn: 2600.2155317	total: 2.57s	remaining: 5.28s
# 327:	learn: 2599.7958874	total: 2.57s	remaining: 5.27s
# 328:	learn: 2598.7699226	total: 2.58s	remaining: 5.26s
# 329:	learn: 2598.2425158	total: 2.61s	remaining: 5.3s
# 330:	learn: 2597.6607841	total: 2.62s	remaining: 5.29s
# 331:	learn: 2596.6587658	total: 2.63s	remaining: 5.29s
# 332:	learn: 2595.7548808	total: 2.64s	remaining: 5.29s
# 333:	learn: 2594.9213710	total: 2.65s	remaining: 5.29s
# 334:	learn: 2594.4979481	total: 2.66s	remaining: 5.28s
# 335:	learn: 2593.3075165	total: 2.67s	remaining: 5.28s
# 336:	learn: 2592.5620484	total: 2.67s	remaining: 5.26s
# 337:	learn: 2591.6388651	total: 2.68s	remaining: 5.26s
# 338:	learn: 2591.2814179	total: 2.7s	remaining: 5.26s
# 339:	learn: 2590.2618819	total: 2.7s	remaining: 5.25s
# 340:	learn: 2589.6201791	total: 2.71s	remaining: 5.24s
# 341:	learn: 2588.8499195	total: 2.72s	remaining: 5.23s
# 342:	learn: 2588.1564495	total: 2.73s	remaining: 5.22s
# 343:	learn: 2587.2720868	total: 2.73s	remaining: 5.21s
# 344:	learn: 2585.9888492	total: 2.74s	remaining: 5.19s
# 345:	learn: 2585.1341031	total: 2.74s	remaining: 5.18s
# 346:	learn: 2584.4946384	total: 2.74s	remaining: 5.16s
# 347:	learn: 2583.4913234	total: 2.75s	remaining: 5.15s
# 348:	learn: 2583.1182462	total: 2.75s	remaining: 5.14s
# 349:	learn: 2582.2665765	total: 2.76s	remaining: 5.13s
# 350:	learn: 2581.7958096	total: 2.78s	remaining: 5.13s
# 351:	learn: 2581.1145661	total: 2.78s	remaining: 5.12s
# 352:	learn: 2580.1952380	total: 2.79s	remaining: 5.11s
# 353:	learn: 2579.2727317	total: 2.79s	remaining: 5.1s
# 354:	learn: 2578.1543192	total: 2.8s	remaining: 5.08s
# 355:	learn: 2577.4448672	total: 2.8s	remaining: 5.07s
# 356:	learn: 2576.6330320	total: 2.81s	remaining: 5.06s
# 357:	learn: 2575.9688919	total: 2.82s	remaining: 5.06s
# 358:	learn: 2575.1398301	total: 2.83s	remaining: 5.05s
# 359:	learn: 2574.4428617	total: 2.83s	remaining: 5.03s
# 360:	learn: 2573.5896600	total: 2.83s	remaining: 5.02s
# 361:	learn: 2572.9765765	total: 2.84s	remaining: 5.01s
# 362:	learn: 2572.0808037	total: 2.85s	remaining: 5s
# 363:	learn: 2571.1431820	total: 2.86s	remaining: 5s
# 364:	learn: 2570.1675549	total: 2.87s	remaining: 4.99s
# 365:	learn: 2568.9548315	total: 2.87s	remaining: 4.98s
# 366:	learn: 2567.8553850	total: 2.88s	remaining: 4.96s
# 367:	learn: 2567.2475327	total: 2.88s	remaining: 4.95s
# 368:	learn: 2566.8429763	total: 2.89s	remaining: 4.94s
# 369:	learn: 2565.8789477	total: 2.89s	remaining: 4.92s
# 370:	learn: 2565.2302460	total: 2.91s	remaining: 4.93s
# 371:	learn: 2564.3695880	total: 2.92s	remaining: 4.93s
# 372:	learn: 2563.8191258	total: 2.95s	remaining: 4.96s
# 373:	learn: 2563.3468068	total: 2.96s	remaining: 4.95s
# 374:	learn: 2562.4329463	total: 2.96s	remaining: 4.93s
# 375:	learn: 2561.5846160	total: 2.96s	remaining: 4.92s
# 376:	learn: 2560.8244210	total: 2.97s	remaining: 4.91s
# 377:	learn: 2559.9978366	total: 2.97s	remaining: 4.89s
# 378:	learn: 2559.1563835	total: 2.98s	remaining: 4.88s
# 379:	learn: 2558.3952748	total: 2.98s	remaining: 4.87s
# 380:	learn: 2557.0271764	total: 2.99s	remaining: 4.86s
# 381:	learn: 2556.4438902	total: 2.99s	remaining: 4.84s
# 382:	learn: 2555.4826394	total: 3s	remaining: 4.83s
# 383:	learn: 2554.0726232	total: 3s	remaining: 4.82s
# 384:	learn: 2553.1111557	total: 3.01s	remaining: 4.8s
# 385:	learn: 2552.5116700	total: 3.01s	remaining: 4.79s
# 386:	learn: 2551.2041693	total: 3.02s	remaining: 4.78s
# 387:	learn: 2550.4940253	total: 3.02s	remaining: 4.76s
# 388:	learn: 2549.7705664	total: 3.02s	remaining: 4.75s
# 389:	learn: 2549.0403579	total: 3.03s	remaining: 4.74s
# 390:	learn: 2548.6753764	total: 3.03s	remaining: 4.73s
# 391:	learn: 2548.0393931	total: 3.04s	remaining: 4.71s
# 392:	learn: 2547.3330121	total: 3.04s	remaining: 4.7s
# 393:	learn: 2546.5903233	total: 3.05s	remaining: 4.69s
# 394:	learn: 2545.2682919	total: 3.06s	remaining: 4.69s
# 395:	learn: 2544.4444262	total: 3.07s	remaining: 4.68s
# 396:	learn: 2543.9575760	total: 3.07s	remaining: 4.67s
# 397:	learn: 2543.3078475	total: 3.08s	remaining: 4.66s
# 398:	learn: 2542.6633276	total: 3.09s	remaining: 4.65s
# 399:	learn: 2542.1283592	total: 3.09s	remaining: 4.64s
# 400:	learn: 2541.5054369	total: 3.1s	remaining: 4.63s
# 401:	learn: 2540.0961021	total: 3.1s	remaining: 4.62s
# 402:	learn: 2539.2857141	total: 3.11s	remaining: 4.61s
# 403:	learn: 2538.8697345	total: 3.11s	remaining: 4.59s
# 404:	learn: 2538.3327500	total: 3.12s	remaining: 4.58s
# 405:	learn: 2537.1916917	total: 3.12s	remaining: 4.57s
# 406:	learn: 2536.4995671	total: 3.13s	remaining: 4.56s
# 407:	learn: 2535.7101627	total: 3.13s	remaining: 4.54s
# 408:	learn: 2534.8558635	total: 3.14s	remaining: 4.53s
# 409:	learn: 2534.2657558	total: 3.14s	remaining: 4.52s
# 410:	learn: 2533.9622034	total: 3.14s	remaining: 4.51s
# 411:	learn: 2533.2683812	total: 3.15s	remaining: 4.49s
# 412:	learn: 2532.3388493	total: 3.15s	remaining: 4.48s
# 413:	learn: 2531.1147468	total: 3.16s	remaining: 4.47s
# 414:	learn: 2530.5132512	total: 3.16s	remaining: 4.46s
# 415:	learn: 2530.0260616	total: 3.17s	remaining: 4.44s
# 416:	learn: 2529.5665620	total: 3.17s	remaining: 4.43s
# 417:	learn: 2528.9485358	total: 3.17s	remaining: 4.42s
# 418:	learn: 2528.2890224	total: 3.18s	remaining: 4.41s
# 419:	learn: 2527.3879587	total: 3.18s	remaining: 4.39s
# 420:	learn: 2526.8488234	total: 3.19s	remaining: 4.38s
# 421:	learn: 2525.7426720	total: 3.19s	remaining: 4.37s
# 422:	learn: 2524.8681679	total: 3.19s	remaining: 4.36s
# 423:	learn: 2523.9699996	total: 3.2s	remaining: 4.34s
# 424:	learn: 2523.3109338	total: 3.2s	remaining: 4.33s
# 425:	learn: 2522.4694484	total: 3.21s	remaining: 4.33s
# 426:	learn: 2520.9088133	total: 3.22s	remaining: 4.32s
# 427:	learn: 2520.2465362	total: 3.22s	remaining: 4.31s
# 428:	learn: 2519.6273268	total: 3.23s	remaining: 4.3s
# 429:	learn: 2518.8067039	total: 3.24s	remaining: 4.29s
# 430:	learn: 2518.0014141	total: 3.24s	remaining: 4.28s
# 431:	learn: 2517.3106737	total: 3.25s	remaining: 4.27s
# 432:	learn: 2516.5547483	total: 3.25s	remaining: 4.26s
# 433:	learn: 2515.6946481	total: 3.26s	remaining: 4.25s
# 434:	learn: 2514.5271007	total: 3.26s	remaining: 4.24s
# 435:	learn: 2514.0189762	total: 3.29s	remaining: 4.25s
# 436:	learn: 2513.0212740	total: 3.29s	remaining: 4.24s
# 437:	learn: 2512.3041420	total: 3.3s	remaining: 4.23s
# 438:	learn: 2511.5450391	total: 3.3s	remaining: 4.22s
# 439:	learn: 2511.0712371	total: 3.31s	remaining: 4.21s
# 440:	learn: 2509.9953504	total: 3.31s	remaining: 4.2s
# 441:	learn: 2509.5769864	total: 3.31s	remaining: 4.18s
# 442:	learn: 2508.9855303	total: 3.32s	remaining: 4.18s
# 443:	learn: 2507.7743790	total: 3.33s	remaining: 4.17s
# 444:	learn: 2507.0587398	total: 3.33s	remaining: 4.15s
# 445:	learn: 2506.4213080	total: 3.33s	remaining: 4.14s
# 446:	learn: 2506.1475955	total: 3.34s	remaining: 4.13s
# 447:	learn: 2505.3948367	total: 3.34s	remaining: 4.12s
# 448:	learn: 2504.9337859	total: 3.35s	remaining: 4.11s
# 449:	learn: 2504.2345963	total: 3.35s	remaining: 4.1s
# 450:	learn: 2503.6618406	total: 3.35s	remaining: 4.08s
# 451:	learn: 2502.8906564	total: 3.36s	remaining: 4.07s
# 452:	learn: 2502.1643935	total: 3.36s	remaining: 4.06s
# 453:	learn: 2501.5098202	total: 3.37s	remaining: 4.05s
# 454:	learn: 2501.2817196	total: 3.38s	remaining: 4.04s
# 455:	learn: 2500.9091091	total: 3.38s	remaining: 4.04s
# 456:	learn: 2499.9952103	total: 3.39s	remaining: 4.03s
# 457:	learn: 2499.2608867	total: 3.4s	remaining: 4.02s
# 458:	learn: 2498.4791487	total: 3.4s	remaining: 4.01s
# 459:	learn: 2497.6275518	total: 3.41s	remaining: 4.01s
# 460:	learn: 2496.2156226	total: 3.42s	remaining: 4s
# 461:	learn: 2495.2673200	total: 3.42s	remaining: 3.99s
# 462:	learn: 2494.4801929	total: 3.43s	remaining: 3.98s
# 463:	learn: 2493.7007786	total: 3.44s	remaining: 3.97s
# 464:	learn: 2492.6182408	total: 3.44s	remaining: 3.96s
# 465:	learn: 2492.1570087	total: 3.51s	remaining: 4.02s
# 466:	learn: 2491.4538516	total: 3.51s	remaining: 4.01s
# 467:	learn: 2490.8162196	total: 3.52s	remaining: 4s
# 468:	learn: 2490.2258016	total: 3.52s	remaining: 3.99s
# 469:	learn: 2489.7644075	total: 3.53s	remaining: 3.98s
# 470:	learn: 2489.0505840	total: 3.53s	remaining: 3.96s
# 471:	learn: 2488.4732114	total: 3.54s	remaining: 3.96s
# 472:	learn: 2487.5852977	total: 3.54s	remaining: 3.95s
# 473:	learn: 2487.1213084	total: 3.55s	remaining: 3.94s
# 474:	learn: 2486.8138137	total: 3.55s	remaining: 3.93s
# 475:	learn: 2486.2101996	total: 3.56s	remaining: 3.92s
# 476:	learn: 2485.0119494	total: 3.56s	remaining: 3.91s
# 477:	learn: 2484.4233033	total: 3.57s	remaining: 3.9s
# 478:	learn: 2483.8095185	total: 3.58s	remaining: 3.89s
# 479:	learn: 2483.2659019	total: 3.58s	remaining: 3.88s
# 480:	learn: 2482.8696646	total: 3.59s	remaining: 3.87s
# 481:	learn: 2482.4023366	total: 3.6s	remaining: 3.87s
# 482:	learn: 2482.1184651	total: 3.6s	remaining: 3.86s
# 483:	learn: 2481.4055111	total: 3.61s	remaining: 3.85s
# 484:	learn: 2480.8489431	total: 3.61s	remaining: 3.83s
# 485:	learn: 2480.4101090	total: 3.62s	remaining: 3.82s
# 486:	learn: 2479.7504699	total: 3.62s	remaining: 3.81s
# 487:	learn: 2479.1338113	total: 3.63s	remaining: 3.8s
# 488:	learn: 2478.3644555	total: 3.63s	remaining: 3.79s
# 489:	learn: 2477.5369370	total: 3.63s	remaining: 3.78s
# 490:	learn: 2476.8146305	total: 3.64s	remaining: 3.77s
# 491:	learn: 2476.1714798	total: 3.64s	remaining: 3.76s
# 492:	learn: 2475.3907942	total: 3.65s	remaining: 3.75s
# 493:	learn: 2474.9980143	total: 3.65s	remaining: 3.74s
# 494:	learn: 2474.6904366	total: 3.66s	remaining: 3.73s
# 495:	learn: 2474.1333270	total: 3.66s	remaining: 3.72s
# 496:	learn: 2473.5799925	total: 3.66s	remaining: 3.71s
# 497:	learn: 2473.0592642	total: 3.67s	remaining: 3.7s
# 498:	learn: 2472.6356224	total: 3.67s	remaining: 3.69s
# 499:	learn: 2471.8413129	total: 3.68s	remaining: 3.68s
# 500:	learn: 2471.3266652	total: 3.68s	remaining: 3.67s
# 501:	learn: 2470.6488398	total: 3.68s	remaining: 3.65s
# 502:	learn: 2470.0488729	total: 3.69s	remaining: 3.65s
# 503:	learn: 2469.6160746	total: 3.7s	remaining: 3.64s
# 504:	learn: 2468.8178450	total: 3.7s	remaining: 3.63s
# 505:	learn: 2468.2290359	total: 3.71s	remaining: 3.62s
# 506:	learn: 2467.6827086	total: 3.72s	remaining: 3.61s
# 507:	learn: 2467.3925475	total: 3.72s	remaining: 3.61s
# 508:	learn: 2466.7776985	total: 3.73s	remaining: 3.6s
# 509:	learn: 2466.1571836	total: 3.73s	remaining: 3.59s
# 510:	learn: 2465.6141998	total: 3.74s	remaining: 3.58s
# 511:	learn: 2464.1131466	total: 3.74s	remaining: 3.57s
# 512:	learn: 2463.3849367	total: 3.75s	remaining: 3.56s
# 513:	learn: 2462.7257407	total: 3.75s	remaining: 3.55s
# 514:	learn: 2462.3824015	total: 3.75s	remaining: 3.54s
# 515:	learn: 2461.3559995	total: 3.76s	remaining: 3.53s
# 516:	learn: 2460.6498938	total: 3.77s	remaining: 3.52s
# 517:	learn: 2459.5733627	total: 3.77s	remaining: 3.51s
# 518:	learn: 2459.2342648	total: 3.78s	remaining: 3.5s
# 519:	learn: 2458.2773283	total: 3.79s	remaining: 3.5s
# 520:	learn: 2457.3514923	total: 3.79s	remaining: 3.48s
# 521:	learn: 2456.4903571	total: 3.79s	remaining: 3.48s
# 522:	learn: 2456.0760988	total: 3.8s	remaining: 3.46s
# 523:	learn: 2455.8769719	total: 3.8s	remaining: 3.45s
# 524:	learn: 2455.2209243	total: 3.81s	remaining: 3.44s
# 525:	learn: 2454.4638938	total: 3.81s	remaining: 3.43s
# 526:	learn: 2453.7433224	total: 3.81s	remaining: 3.42s
# 527:	learn: 2452.9299695	total: 3.82s	remaining: 3.41s
# 528:	learn: 2452.3659423	total: 3.82s	remaining: 3.4s
# 529:	learn: 2451.5267260	total: 3.83s	remaining: 3.4s
# 530:	learn: 2450.6768609	total: 3.83s	remaining: 3.39s
# 531:	learn: 2450.3902698	total: 3.84s	remaining: 3.38s
# 532:	learn: 2449.7499110	total: 3.85s	remaining: 3.37s
# 533:	learn: 2449.2378773	total: 3.86s	remaining: 3.37s
# 534:	learn: 2448.5875504	total: 3.87s	remaining: 3.36s
# 535:	learn: 2447.8384266	total: 3.88s	remaining: 3.35s
# 536:	learn: 2447.4298164	total: 3.88s	remaining: 3.35s
# 537:	learn: 2447.1750089	total: 3.89s	remaining: 3.34s
# 538:	learn: 2446.1344754	total: 3.9s	remaining: 3.33s
# 539:	learn: 2445.3177261	total: 3.9s	remaining: 3.32s
# 540:	learn: 2444.3474348	total: 3.9s	remaining: 3.31s
# 541:	learn: 2443.8918923	total: 3.91s	remaining: 3.3s
# 542:	learn: 2443.0389904	total: 3.91s	remaining: 3.29s
# 543:	learn: 2442.7004594	total: 3.92s	remaining: 3.28s
# 544:	learn: 2442.2467680	total: 3.92s	remaining: 3.27s
# 545:	learn: 2441.9848546	total: 3.93s	remaining: 3.27s
# 546:	learn: 2441.4347741	total: 3.93s	remaining: 3.25s
# 547:	learn: 2440.9655400	total: 3.94s	remaining: 3.25s
# 548:	learn: 2440.5357619	total: 3.94s	remaining: 3.24s
# 549:	learn: 2439.9834290	total: 3.94s	remaining: 3.23s
# 550:	learn: 2439.4856124	total: 3.95s	remaining: 3.22s
# 551:	learn: 2438.7736058	total: 3.95s	remaining: 3.21s
# 552:	learn: 2438.2978748	total: 3.96s	remaining: 3.2s
# 553:	learn: 2437.9000260	total: 3.96s	remaining: 3.19s
# 554:	learn: 2437.4055085	total: 3.96s	remaining: 3.18s
# 555:	learn: 2437.0865898	total: 3.97s	remaining: 3.17s
# 556:	learn: 2436.4863418	total: 3.97s	remaining: 3.16s
# 557:	learn: 2435.8506293	total: 3.98s	remaining: 3.15s
# 558:	learn: 2434.8215862	total: 3.98s	remaining: 3.14s
# 559:	learn: 2434.4284017	total: 3.98s	remaining: 3.13s
# 560:	learn: 2433.4128424	total: 3.99s	remaining: 3.12s
# 561:	learn: 2432.7642779	total: 3.99s	remaining: 3.11s
# 562:	learn: 2432.3440060	total: 4s	remaining: 3.1s
# 563:	learn: 2431.7539302	total: 4.01s	remaining: 3.1s
# 564:	learn: 2431.0899699	total: 4.01s	remaining: 3.09s
# 565:	learn: 2430.5925524	total: 4.02s	remaining: 3.08s
# 566:	learn: 2429.7222059	total: 4.03s	remaining: 3.07s
# 567:	learn: 2429.2704745	total: 4.03s	remaining: 3.07s
# 568:	learn: 2428.8062484	total: 4.04s	remaining: 3.06s
# 569:	learn: 2428.3356653	total: 4.04s	remaining: 3.05s
# 570:	learn: 2427.6748515	total: 4.05s	remaining: 3.04s
# 571:	learn: 2427.1868466	total: 4.05s	remaining: 3.03s
# 572:	learn: 2426.5483078	total: 4.06s	remaining: 3.02s
# 573:	learn: 2425.8684239	total: 4.08s	remaining: 3.03s
# 574:	learn: 2425.2604737	total: 4.09s	remaining: 3.03s
# 575:	learn: 2424.6832643	total: 4.1s	remaining: 3.02s
# 576:	learn: 2424.2322145	total: 4.11s	remaining: 3.01s
# 577:	learn: 2423.9594403	total: 4.11s	remaining: 3s
# 578:	learn: 2423.5719424	total: 4.11s	remaining: 2.99s
# 579:	learn: 2422.4839400	total: 4.12s	remaining: 2.98s
# 580:	learn: 2422.0002958	total: 4.13s	remaining: 2.98s
# 581:	learn: 2421.4077657	total: 4.14s	remaining: 2.97s
# 582:	learn: 2420.8709356	total: 4.15s	remaining: 2.97s
# 583:	learn: 2420.4986268	total: 4.16s	remaining: 2.96s
# 584:	learn: 2419.9012038	total: 4.22s	remaining: 2.99s
# 585:	learn: 2419.3353778	total: 4.23s	remaining: 2.99s
# 586:	learn: 2418.7862326	total: 4.24s	remaining: 2.98s
# 587:	learn: 2418.1432106	total: 4.24s	remaining: 2.97s
# 588:	learn: 2417.3855360	total: 4.25s	remaining: 2.96s
# 589:	learn: 2416.5916766	total: 4.26s	remaining: 2.96s
# 590:	learn: 2416.1491952	total: 4.27s	remaining: 2.96s
# 591:	learn: 2415.7498476	total: 4.28s	remaining: 2.95s
# 592:	learn: 2415.1434078	total: 4.29s	remaining: 2.94s
# 593:	learn: 2414.5006747	total: 4.29s	remaining: 2.93s
# 594:	learn: 2413.8622596	total: 4.3s	remaining: 2.93s
# 595:	learn: 2413.0770393	total: 4.31s	remaining: 2.92s
# 596:	learn: 2411.9421383	total: 4.38s	remaining: 2.95s
# 597:	learn: 2411.1206176	total: 4.38s	remaining: 2.95s
# 598:	learn: 2410.4525715	total: 4.39s	remaining: 2.94s
# 599:	learn: 2410.0086363	total: 4.39s	remaining: 2.93s
# 600:	learn: 2409.6849393	total: 4.4s	remaining: 2.92s
# 601:	learn: 2408.9406288	total: 4.4s	remaining: 2.91s
# 602:	learn: 2408.4859915	total: 4.41s	remaining: 2.9s
# 603:	learn: 2407.9558477	total: 4.41s	remaining: 2.89s
# 604:	learn: 2407.7850394	total: 4.42s	remaining: 2.88s
# 605:	learn: 2407.0265830	total: 4.42s	remaining: 2.88s
# 606:	learn: 2406.5435021	total: 4.43s	remaining: 2.87s
# 607:	learn: 2406.0910816	total: 4.43s	remaining: 2.86s
# 608:	learn: 2405.1738192	total: 4.45s	remaining: 2.86s
# 609:	learn: 2404.4926749	total: 4.46s	remaining: 2.85s
# 610:	learn: 2403.9574629	total: 4.47s	remaining: 2.84s
# 611:	learn: 2403.3752462	total: 4.47s	remaining: 2.83s
# 612:	learn: 2402.9866373	total: 4.47s	remaining: 2.83s
# 613:	learn: 2402.2734203	total: 4.48s	remaining: 2.82s
# 614:	learn: 2401.4993248	total: 4.49s	remaining: 2.81s
# 615:	learn: 2400.8138425	total: 4.49s	remaining: 2.8s
# 616:	learn: 2400.2871091	total: 4.51s	remaining: 2.8s
# 617:	learn: 2399.9422028	total: 4.51s	remaining: 2.79s
# 618:	learn: 2399.3048452	total: 4.52s	remaining: 2.78s
# 619:	learn: 2398.7665424	total: 4.53s	remaining: 2.78s
# 620:	learn: 2398.2794302	total: 4.54s	remaining: 2.77s
# 621:	learn: 2397.3883882	total: 4.54s	remaining: 2.76s
# 622:	learn: 2396.1988532	total: 4.55s	remaining: 2.75s
# 623:	learn: 2395.7153720	total: 4.55s	remaining: 2.74s
# 624:	learn: 2394.9149971	total: 4.56s	remaining: 2.74s
# 625:	learn: 2394.3800441	total: 4.57s	remaining: 2.73s
# 626:	learn: 2393.9620023	total: 4.57s	remaining: 2.72s
# 627:	learn: 2393.5899362	total: 4.58s	remaining: 2.71s
# 628:	learn: 2392.9873524	total: 4.59s	remaining: 2.71s
# 629:	learn: 2392.3643692	total: 4.59s	remaining: 2.7s
# 630:	learn: 2391.6218461	total: 4.59s	remaining: 2.69s
# 631:	learn: 2390.9656050	total: 4.6s	remaining: 2.68s
# 632:	learn: 2390.3636012	total: 4.6s	remaining: 2.67s
# 633:	learn: 2389.6880783	total: 4.61s	remaining: 2.66s
# 634:	learn: 2389.4043144	total: 4.61s	remaining: 2.65s
# 635:	learn: 2388.6757632	total: 4.62s	remaining: 2.64s
# 636:	learn: 2388.0870179	total: 4.62s	remaining: 2.63s
# 637:	learn: 2387.4904785	total: 4.63s	remaining: 2.63s
# 638:	learn: 2386.9145558	total: 4.63s	remaining: 2.62s
# 639:	learn: 2386.0396112	total: 4.64s	remaining: 2.61s
# 640:	learn: 2385.6691669	total: 4.64s	remaining: 2.6s
# 641:	learn: 2385.2047695	total: 4.64s	remaining: 2.59s
# 642:	learn: 2384.6245298	total: 4.65s	remaining: 2.58s
# 643:	learn: 2383.7867783	total: 4.66s	remaining: 2.57s
# 644:	learn: 2383.3110553	total: 4.66s	remaining: 2.56s
# 645:	learn: 2382.4530613	total: 4.66s	remaining: 2.56s
# 646:	learn: 2381.9358158	total: 4.67s	remaining: 2.55s
# 647:	learn: 2381.3508551	total: 4.68s	remaining: 2.54s
# 648:	learn: 2380.7488381	total: 4.68s	remaining: 2.53s
# 649:	learn: 2380.3833955	total: 4.69s	remaining: 2.52s
# 650:	learn: 2379.8668953	total: 4.69s	remaining: 2.52s
# 651:	learn: 2379.5152187	total: 4.7s	remaining: 2.51s
# 652:	learn: 2378.9081237	total: 4.7s	remaining: 2.5s
# 653:	learn: 2378.2602374	total: 4.71s	remaining: 2.49s
# 654:	learn: 2377.7217233	total: 4.72s	remaining: 2.48s
# 655:	learn: 2377.1375246	total: 4.72s	remaining: 2.48s
# 656:	learn: 2376.5179666	total: 4.73s	remaining: 2.47s
# 657:	learn: 2375.9826297	total: 4.73s	remaining: 2.46s
# 658:	learn: 2375.5645528	total: 4.74s	remaining: 2.45s
# 659:	learn: 2374.9995553	total: 4.74s	remaining: 2.44s
# 660:	learn: 2374.5995680	total: 4.77s	remaining: 2.44s
# 661:	learn: 2374.0555552	total: 4.77s	remaining: 2.44s
# 662:	learn: 2373.5882873	total: 4.78s	remaining: 2.43s
# 663:	learn: 2373.2273212	total: 4.78s	remaining: 2.42s
# 664:	learn: 2372.5558513	total: 4.79s	remaining: 2.41s
# 665:	learn: 2372.1809271	total: 4.79s	remaining: 2.4s
# 666:	learn: 2371.7381335	total: 4.81s	remaining: 2.4s
# 667:	learn: 2371.1190750	total: 4.82s	remaining: 2.39s
# 668:	learn: 2370.6918603	total: 4.82s	remaining: 2.39s
# 669:	learn: 2370.3870265	total: 4.83s	remaining: 2.38s
# 670:	learn: 2370.0029363	total: 4.83s	remaining: 2.37s
# 671:	learn: 2369.6855516	total: 4.84s	remaining: 2.36s
# 672:	learn: 2369.0171702	total: 4.84s	remaining: 2.35s
# 673:	learn: 2368.5658731	total: 4.84s	remaining: 2.34s
# 674:	learn: 2368.1579244	total: 4.85s	remaining: 2.33s
# 675:	learn: 2367.4106122	total: 4.86s	remaining: 2.33s
# 676:	learn: 2366.8159089	total: 4.86s	remaining: 2.32s
# 677:	learn: 2366.6215579	total: 4.87s	remaining: 2.31s
# 678:	learn: 2366.4260753	total: 4.88s	remaining: 2.31s
# 679:	learn: 2365.8408160	total: 4.89s	remaining: 2.3s
# 680:	learn: 2365.4439310	total: 4.89s	remaining: 2.29s
# 681:	learn: 2364.3481491	total: 4.9s	remaining: 2.28s
# 682:	learn: 2363.7477387	total: 4.9s	remaining: 2.27s
# 683:	learn: 2363.4987382	total: 4.91s	remaining: 2.27s
# 684:	learn: 2363.1088305	total: 4.91s	remaining: 2.26s
# 685:	learn: 2362.7200775	total: 4.92s	remaining: 2.25s
# 686:	learn: 2362.3044432	total: 4.93s	remaining: 2.25s
# 687:	learn: 2361.3258991	total: 4.93s	remaining: 2.24s
# 688:	learn: 2360.6132046	total: 4.94s	remaining: 2.23s
# 689:	learn: 2359.9754211	total: 4.94s	remaining: 2.22s
# 690:	learn: 2359.0570121	total: 4.95s	remaining: 2.21s
# 691:	learn: 2358.2673501	total: 4.95s	remaining: 2.21s
# 692:	learn: 2357.7087208	total: 4.96s	remaining: 2.2s
# 693:	learn: 2357.5574929	total: 4.96s	remaining: 2.19s
# 694:	learn: 2357.2443648	total: 4.97s	remaining: 2.18s
# 695:	learn: 2356.6900229	total: 4.98s	remaining: 2.17s
# 696:	learn: 2356.0019947	total: 4.98s	remaining: 2.17s
# 697:	learn: 2355.7217435	total: 4.99s	remaining: 2.16s
# 698:	learn: 2355.3182282	total: 4.99s	remaining: 2.15s
# 699:	learn: 2354.5232398	total: 4.99s	remaining: 2.14s
# 700:	learn: 2354.1969547	total: 5s	remaining: 2.13s
# 701:	learn: 2353.6222229	total: 5s	remaining: 2.12s
# 702:	learn: 2353.2048138	total: 5.01s	remaining: 2.12s
# 703:	learn: 2352.9370116	total: 5.01s	remaining: 2.11s
# 704:	learn: 2352.4682293	total: 5.02s	remaining: 2.1s
# 705:	learn: 2352.2551689	total: 5.04s	remaining: 2.1s
# 706:	learn: 2351.5439669	total: 5.04s	remaining: 2.09s
# 707:	learn: 2351.0086964	total: 5.05s	remaining: 2.08s
# 708:	learn: 2350.1260802	total: 5.05s	remaining: 2.07s
# 709:	learn: 2349.4584369	total: 5.06s	remaining: 2.06s
# 710:	learn: 2348.9184261	total: 5.06s	remaining: 2.06s
# 711:	learn: 2348.5554796	total: 5.08s	remaining: 2.05s
# 712:	learn: 2348.0930242	total: 5.08s	remaining: 2.04s
# 713:	learn: 2347.6690388	total: 5.08s	remaining: 2.04s
# 714:	learn: 2347.4250450	total: 5.09s	remaining: 2.03s
# 715:	learn: 2347.0508177	total: 5.09s	remaining: 2.02s
# 716:	learn: 2346.5584812	total: 5.1s	remaining: 2.01s
# 717:	learn: 2346.1335900	total: 5.1s	remaining: 2s
# 718:	learn: 2345.5527280	total: 5.11s	remaining: 2s
# 719:	learn: 2345.1841798	total: 5.11s	remaining: 1.99s
# 720:	learn: 2344.5111833	total: 5.12s	remaining: 1.98s
# 721:	learn: 2344.0571044	total: 5.15s	remaining: 1.98s
# 722:	learn: 2343.5812205	total: 5.16s	remaining: 1.98s
# 723:	learn: 2342.9175725	total: 5.16s	remaining: 1.97s
# 724:	learn: 2341.8445051	total: 5.17s	remaining: 1.96s
# 725:	learn: 2341.2287907	total: 5.17s	remaining: 1.95s
# 726:	learn: 2340.8038724	total: 5.21s	remaining: 1.96s
# 727:	learn: 2340.1238837	total: 5.21s	remaining: 1.95s
# 728:	learn: 2339.6719934	total: 5.22s	remaining: 1.94s
# 729:	learn: 2339.4791432	total: 5.23s	remaining: 1.93s
# 730:	learn: 2338.9259723	total: 5.23s	remaining: 1.93s
# 731:	learn: 2338.4581945	total: 5.24s	remaining: 1.92s
# 732:	learn: 2338.0687892	total: 5.24s	remaining: 1.91s
# 733:	learn: 2337.8891752	total: 5.25s	remaining: 1.9s
# 734:	learn: 2337.3669565	total: 5.26s	remaining: 1.9s
# 735:	learn: 2336.9300917	total: 5.27s	remaining: 1.89s
# 736:	learn: 2336.2946681	total: 5.28s	remaining: 1.88s
# 737:	learn: 2335.4809052	total: 5.28s	remaining: 1.88s
# 738:	learn: 2334.7406119	total: 5.29s	remaining: 1.87s
# 739:	learn: 2333.9070098	total: 5.3s	remaining: 1.86s
# 740:	learn: 2333.5276191	total: 5.3s	remaining: 1.85s
# 741:	learn: 2333.0435905	total: 5.31s	remaining: 1.85s
# 742:	learn: 2332.5666069	total: 5.32s	remaining: 1.84s
# 743:	learn: 2332.1391482	total: 5.32s	remaining: 1.83s
# 744:	learn: 2331.8742176	total: 5.33s	remaining: 1.82s
# 745:	learn: 2331.6901701	total: 5.33s	remaining: 1.82s
# 746:	learn: 2331.3887508	total: 5.34s	remaining: 1.81s
# 747:	learn: 2331.1653184	total: 5.34s	remaining: 1.8s
# 748:	learn: 2330.7466847	total: 5.35s	remaining: 1.79s
# 749:	learn: 2330.3732465	total: 5.35s	remaining: 1.78s
# 750:	learn: 2329.7360202	total: 5.36s	remaining: 1.78s
# 751:	learn: 2329.3436135	total: 5.37s	remaining: 1.77s
# 752:	learn: 2328.8961470	total: 5.38s	remaining: 1.76s
# 753:	learn: 2328.4696672	total: 5.38s	remaining: 1.76s
# 754:	learn: 2327.8010192	total: 5.39s	remaining: 1.75s
# 755:	learn: 2326.9917975	total: 5.4s	remaining: 1.74s
# 756:	learn: 2326.4361537	total: 5.4s	remaining: 1.73s
# 757:	learn: 2325.9274605	total: 5.41s	remaining: 1.73s
# 758:	learn: 2325.3505272	total: 5.41s	remaining: 1.72s
# 759:	learn: 2324.7623251	total: 5.43s	remaining: 1.71s
# 760:	learn: 2324.3623856	total: 5.43s	remaining: 1.71s
# 761:	learn: 2324.0621219	total: 5.44s	remaining: 1.7s
# 762:	learn: 2323.2443925	total: 5.44s	remaining: 1.69s
# 763:	learn: 2322.7406795	total: 5.45s	remaining: 1.68s
# 764:	learn: 2322.0553529	total: 5.46s	remaining: 1.68s
# 765:	learn: 2321.4477996	total: 5.46s	remaining: 1.67s
# 766:	learn: 2321.0994839	total: 5.47s	remaining: 1.66s
# 767:	learn: 2319.9531277	total: 5.48s	remaining: 1.65s
# 768:	learn: 2319.4094291	total: 5.48s	remaining: 1.65s
# 769:	learn: 2319.0562122	total: 5.49s	remaining: 1.64s
# 770:	learn: 2318.7223794	total: 5.5s	remaining: 1.63s
# 771:	learn: 2317.9023166	total: 5.5s	remaining: 1.63s
# 772:	learn: 2317.5811423	total: 5.51s	remaining: 1.62s
# 773:	learn: 2317.1793725	total: 5.52s	remaining: 1.61s
# 774:	learn: 2316.8779425	total: 5.55s	remaining: 1.61s
# 775:	learn: 2316.3014601	total: 5.56s	remaining: 1.6s
# 776:	learn: 2315.9239471	total: 5.57s	remaining: 1.6s
# 777:	learn: 2315.4238616	total: 5.57s	remaining: 1.59s
# 778:	learn: 2315.1728808	total: 5.58s	remaining: 1.58s
# 779:	learn: 2314.6849872	total: 5.58s	remaining: 1.57s
# 780:	learn: 2314.2081891	total: 5.59s	remaining: 1.57s
# 781:	learn: 2313.5739951	total: 5.59s	remaining: 1.56s
# 782:	learn: 2313.2472538	total: 5.59s	remaining: 1.55s
# 783:	learn: 2312.7826472	total: 5.6s	remaining: 1.54s
# 784:	learn: 2311.9523058	total: 5.61s	remaining: 1.53s
# 785:	learn: 2311.6951677	total: 5.65s	remaining: 1.54s
# 786:	learn: 2311.1771089	total: 5.66s	remaining: 1.53s
# 787:	learn: 2310.8204420	total: 5.66s	remaining: 1.52s
# 788:	learn: 2310.6172516	total: 5.67s	remaining: 1.51s
# 789:	learn: 2309.8025429	total: 5.67s	remaining: 1.51s
# 790:	learn: 2309.4591187	total: 5.68s	remaining: 1.5s
# 791:	learn: 2309.1124738	total: 5.69s	remaining: 1.49s
# 792:	learn: 2308.8085490	total: 5.69s	remaining: 1.49s
# 793:	learn: 2308.2479896	total: 5.7s	remaining: 1.48s
# 794:	learn: 2307.3436610	total: 5.7s	remaining: 1.47s
# 795:	learn: 2306.5084753	total: 5.71s	remaining: 1.46s
# 796:	learn: 2305.8577087	total: 5.71s	remaining: 1.46s
# 797:	learn: 2305.1920788	total: 5.72s	remaining: 1.45s
# 798:	learn: 2304.6352704	total: 5.76s	remaining: 1.45s
# 799:	learn: 2303.9727511	total: 5.77s	remaining: 1.44s
# 800:	learn: 2303.5495274	total: 5.78s	remaining: 1.44s
# 801:	learn: 2303.1167842	total: 5.78s	remaining: 1.43s
# 802:	learn: 2302.6288460	total: 5.79s	remaining: 1.42s
# 803:	learn: 2302.3351116	total: 5.79s	remaining: 1.41s
# 804:	learn: 2301.7455745	total: 5.8s	remaining: 1.4s
# 805:	learn: 2301.0267247	total: 5.8s	remaining: 1.4s
# 806:	learn: 2300.7818319	total: 5.83s	remaining: 1.39s
# 807:	learn: 2300.2193941	total: 5.83s	remaining: 1.39s
# 808:	learn: 2299.8686705	total: 5.83s	remaining: 1.38s
# 809:	learn: 2299.4880431	total: 5.84s	remaining: 1.37s
# 810:	learn: 2299.0439999	total: 5.85s	remaining: 1.36s
# 811:	learn: 2298.1500342	total: 5.86s	remaining: 1.36s
# 812:	learn: 2297.7495317	total: 5.87s	remaining: 1.35s
# 813:	learn: 2297.1392936	total: 5.88s	remaining: 1.34s
# 814:	learn: 2296.8710772	total: 5.88s	remaining: 1.33s
# 815:	learn: 2296.6243672	total: 5.89s	remaining: 1.33s
# 816:	learn: 2295.7580164	total: 5.89s	remaining: 1.32s
# 817:	learn: 2295.5525413	total: 5.9s	remaining: 1.31s
# 818:	learn: 2295.1373269	total: 5.9s	remaining: 1.3s
# 819:	learn: 2294.6120844	total: 5.91s	remaining: 1.3s
# 820:	learn: 2294.0784256	total: 5.92s	remaining: 1.29s
# 821:	learn: 2293.7249462	total: 5.92s	remaining: 1.28s
# 822:	learn: 2293.3070727	total: 5.93s	remaining: 1.27s
# 823:	learn: 2292.4221771	total: 5.94s	remaining: 1.27s
# 824:	learn: 2292.1432749	total: 5.95s	remaining: 1.26s
# 825:	learn: 2291.5971496	total: 5.96s	remaining: 1.25s
# 826:	learn: 2291.1885564	total: 5.97s	remaining: 1.25s
# 827:	learn: 2290.8006421	total: 5.97s	remaining: 1.24s
# 828:	learn: 2290.2464717	total: 5.97s	remaining: 1.23s
# 829:	learn: 2289.3975098	total: 5.98s	remaining: 1.23s
# 830:	learn: 2289.0502571	total: 5.99s	remaining: 1.22s
# 831:	learn: 2288.5996655	total: 5.99s	remaining: 1.21s
# 832:	learn: 2288.2636500	total: 6s	remaining: 1.2s
# 833:	learn: 2287.9423005	total: 6.01s	remaining: 1.2s
# 834:	learn: 2287.4099296	total: 6.01s	remaining: 1.19s
# 835:	learn: 2286.8435818	total: 6.04s	remaining: 1.19s
# 836:	learn: 2286.2572682	total: 6.05s	remaining: 1.18s
# 837:	learn: 2285.7343302	total: 6.06s	remaining: 1.17s
# 838:	learn: 2285.1882500	total: 6.06s	remaining: 1.16s
# 839:	learn: 2284.9420296	total: 6.07s	remaining: 1.16s
# 840:	learn: 2284.7136945	total: 6.08s	remaining: 1.15s
# 841:	learn: 2284.2440080	total: 6.08s	remaining: 1.14s
# 842:	learn: 2283.8107087	total: 6.09s	remaining: 1.13s
# 843:	learn: 2283.4106455	total: 6.09s	remaining: 1.13s
# 844:	learn: 2282.3236709	total: 6.1s	remaining: 1.12s
# 845:	learn: 2281.9102744	total: 6.1s	remaining: 1.11s
# 846:	learn: 2281.1762777	total: 6.11s	remaining: 1.1s
# 847:	learn: 2280.8208954	total: 6.12s	remaining: 1.1s
# 848:	learn: 2280.1642166	total: 6.12s	remaining: 1.09s
# 849:	learn: 2279.8448581	total: 6.13s	remaining: 1.08s
# 850:	learn: 2279.4560078	total: 6.13s	remaining: 1.07s
# 851:	learn: 2278.9370215	total: 6.14s	remaining: 1.06s
# 852:	learn: 2278.5625674	total: 6.14s	remaining: 1.06s
# 853:	learn: 2278.0617619	total: 6.15s	remaining: 1.05s
# 854:	learn: 2277.6741233	total: 6.15s	remaining: 1.04s
# 855:	learn: 2277.0132479	total: 6.16s	remaining: 1.03s
# 856:	learn: 2276.5934384	total: 6.16s	remaining: 1.03s
# 857:	learn: 2276.1067180	total: 6.17s	remaining: 1.02s
# 858:	learn: 2275.5642989	total: 6.17s	remaining: 1.01s
# 859:	learn: 2275.1463799	total: 6.18s	remaining: 1s
# 860:	learn: 2274.5557853	total: 6.19s	remaining: 1s
# 861:	learn: 2274.2895512	total: 6.2s	remaining: 993ms
# 862:	learn: 2273.8275922	total: 6.21s	remaining: 986ms
# 863:	learn: 2273.3663158	total: 6.22s	remaining: 979ms
# 864:	learn: 2273.2533317	total: 6.22s	remaining: 971ms
# 865:	learn: 2272.5809498	total: 6.23s	remaining: 963ms
# 866:	learn: 2272.0879047	total: 6.23s	remaining: 956ms
# 867:	learn: 2271.5130945	total: 6.24s	remaining: 949ms
# 868:	learn: 2270.7980249	total: 6.24s	remaining: 941ms
# 869:	learn: 2270.2961275	total: 6.25s	remaining: 934ms
# 870:	learn: 2270.0018091	total: 6.25s	remaining: 926ms
# 871:	learn: 2269.5050906	total: 6.26s	remaining: 919ms
# 872:	learn: 2269.0171277	total: 6.26s	remaining: 911ms
# 873:	learn: 2268.5884344	total: 6.27s	remaining: 904ms
# 874:	learn: 2268.2626437	total: 6.27s	remaining: 896ms
# 875:	learn: 2267.8008491	total: 6.28s	remaining: 889ms
# 876:	learn: 2267.3851224	total: 6.28s	remaining: 881ms
# 877:	learn: 2267.2278670	total: 6.29s	remaining: 874ms
# 878:	learn: 2267.0260717	total: 6.29s	remaining: 866ms
# 879:	learn: 2266.5297179	total: 6.3s	remaining: 859ms
# 880:	learn: 2266.2031786	total: 6.3s	remaining: 852ms
# 881:	learn: 2265.8980886	total: 6.31s	remaining: 845ms
# 882:	learn: 2265.1295050	total: 6.32s	remaining: 838ms
# 883:	learn: 2264.8532094	total: 6.33s	remaining: 830ms
# 884:	learn: 2264.3348328	total: 6.33s	remaining: 823ms
# 885:	learn: 2263.8551922	total: 6.34s	remaining: 816ms
# 886:	learn: 2263.5741658	total: 6.34s	remaining: 808ms
# 887:	learn: 2263.2730404	total: 6.35s	remaining: 801ms
# 888:	learn: 2262.6752970	total: 6.35s	remaining: 793ms
# 889:	learn: 2262.0300470	total: 6.36s	remaining: 786ms
# 890:	learn: 2261.2856665	total: 6.36s	remaining: 778ms
# 891:	learn: 2261.0286671	total: 6.37s	remaining: 771ms
# 892:	learn: 2260.6804404	total: 6.37s	remaining: 764ms
# 893:	learn: 2260.1381527	total: 6.38s	remaining: 756ms
# 894:	learn: 2259.0016374	total: 6.39s	remaining: 749ms
# 895:	learn: 2258.5083025	total: 6.39s	remaining: 742ms
# 896:	learn: 2258.0274258	total: 6.4s	remaining: 735ms
# 897:	learn: 2257.7592162	total: 6.4s	remaining: 727ms
# 898:	learn: 2257.2934756	total: 6.41s	remaining: 720ms
# 899:	learn: 2256.7060666	total: 6.41s	remaining: 712ms
# 900:	learn: 2256.0072944	total: 6.42s	remaining: 705ms
# 901:	learn: 2255.5597654	total: 6.42s	remaining: 698ms
# 902:	learn: 2255.2662411	total: 6.43s	remaining: 690ms
# 903:	learn: 2254.9071892	total: 6.43s	remaining: 683ms
# 904:	learn: 2254.7556344	total: 6.44s	remaining: 676ms
# 905:	learn: 2254.1466021	total: 6.44s	remaining: 668ms
# 906:	learn: 2253.5857484	total: 6.45s	remaining: 661ms
# 907:	learn: 2252.9386391	total: 6.45s	remaining: 654ms
# 908:	learn: 2252.4376243	total: 6.46s	remaining: 646ms
# 909:	learn: 2252.1058528	total: 6.46s	remaining: 639ms
# 910:	learn: 2251.6798858	total: 6.47s	remaining: 632ms
# 911:	learn: 2251.2684378	total: 6.47s	remaining: 625ms
# 912:	learn: 2250.7982202	total: 6.48s	remaining: 618ms
# 913:	learn: 2249.6756521	total: 6.49s	remaining: 611ms
# 914:	learn: 2248.8896295	total: 6.5s	remaining: 604ms
# 915:	learn: 2248.1532394	total: 6.5s	remaining: 596ms
# 916:	learn: 2247.7204778	total: 6.5s	remaining: 589ms
# 917:	learn: 2247.2847665	total: 6.51s	remaining: 582ms
# 918:	learn: 2247.1077048	total: 6.52s	remaining: 575ms
# 919:	learn: 2246.5316499	total: 6.52s	remaining: 567ms
# 920:	learn: 2246.3412590	total: 6.53s	remaining: 560ms
# 921:	learn: 2246.0266567	total: 6.53s	remaining: 553ms
# 922:	learn: 2245.4997838	total: 6.54s	remaining: 545ms
# 923:	learn: 2245.0107987	total: 6.54s	remaining: 538ms
# 924:	learn: 2243.9886912	total: 6.55s	remaining: 531ms
# 925:	learn: 2243.1146843	total: 6.55s	remaining: 524ms
# 926:	learn: 2242.5896504	total: 6.56s	remaining: 516ms
# 927:	learn: 2242.2870550	total: 6.56s	remaining: 509ms
# 928:	learn: 2242.0652960	total: 6.57s	remaining: 502ms
# 929:	learn: 2241.2306060	total: 6.57s	remaining: 495ms
# 930:	learn: 2240.6013469	total: 6.58s	remaining: 487ms
# 931:	learn: 2239.9793266	total: 6.58s	remaining: 480ms
# 932:	learn: 2239.5250922	total: 6.59s	remaining: 474ms
# 933:	learn: 2239.1635733	total: 6.6s	remaining: 466ms
# 934:	learn: 2238.5430411	total: 6.61s	remaining: 459ms
# 935:	learn: 2237.9063901	total: 6.61s	remaining: 452ms
# 936:	learn: 2237.3748655	total: 6.62s	remaining: 445ms
# 937:	learn: 2237.0592408	total: 6.62s	remaining: 438ms
# 938:	learn: 2236.6264783	total: 6.63s	remaining: 431ms
# 939:	learn: 2236.2712530	total: 6.63s	remaining: 423ms
# 940:	learn: 2235.5976595	total: 6.64s	remaining: 416ms
# 941:	learn: 2234.9337475	total: 6.64s	remaining: 409ms
# 942:	learn: 2234.6343092	total: 6.65s	remaining: 402ms
# 943:	learn: 2234.4601121	total: 6.65s	remaining: 395ms
# 944:	learn: 2233.9691503	total: 6.67s	remaining: 388ms
# 945:	learn: 2233.4829409	total: 6.68s	remaining: 381ms
# 946:	learn: 2233.0778064	total: 6.68s	remaining: 374ms
# 947:	learn: 2232.2988551	total: 6.69s	remaining: 367ms
# 948:	learn: 2231.8589452	total: 6.69s	remaining: 360ms
# 949:	learn: 2231.5666941	total: 6.7s	remaining: 352ms
# 950:	learn: 2231.1161250	total: 6.7s	remaining: 345ms
# 951:	learn: 2230.5502664	total: 6.71s	remaining: 338ms
# 952:	learn: 2230.0482264	total: 6.71s	remaining: 331ms
# 953:	learn: 2229.4359214	total: 6.72s	remaining: 324ms
# 954:	learn: 2229.0577109	total: 6.72s	remaining: 317ms
# 955:	learn: 2228.2068912	total: 6.72s	remaining: 310ms
# 956:	learn: 2228.0339751	total: 6.73s	remaining: 302ms
# 957:	learn: 2227.5106851	total: 6.75s	remaining: 296ms
# 958:	learn: 2226.6881564	total: 6.75s	remaining: 289ms
# 959:	learn: 2226.1751908	total: 6.76s	remaining: 282ms
# 960:	learn: 2225.8592943	total: 6.76s	remaining: 274ms
# 961:	learn: 2225.5376998	total: 6.77s	remaining: 267ms
# 962:	learn: 2224.9816511	total: 6.77s	remaining: 260ms
# 963:	learn: 2224.6842081	total: 6.78s	remaining: 253ms
# 964:	learn: 2224.4792736	total: 6.79s	remaining: 246ms
# 965:	learn: 2224.2316505	total: 6.8s	remaining: 239ms
# 966:	learn: 2223.9305147	total: 6.8s	remaining: 232ms
# 967:	learn: 2223.4060139	total: 6.81s	remaining: 225ms
# 968:	learn: 2222.7620914	total: 6.81s	remaining: 218ms
# 969:	learn: 2222.4883825	total: 6.82s	remaining: 211ms
# 970:	learn: 2222.2082718	total: 6.87s	remaining: 205ms
# 971:	learn: 2221.8291003	total: 6.87s	remaining: 198ms
# 972:	learn: 2221.3286731	total: 6.88s	remaining: 191ms
# 973:	learn: 2220.9962239	total: 6.88s	remaining: 184ms
# 974:	learn: 2220.7126213	total: 6.89s	remaining: 177ms
# 975:	learn: 2220.2667362	total: 6.89s	remaining: 169ms
# 976:	learn: 2219.9334973	total: 6.9s	remaining: 162ms
# 977:	learn: 2219.2036240	total: 6.9s	remaining: 155ms
# 978:	learn: 2218.8804159	total: 6.91s	remaining: 148ms
# 979:	learn: 2218.4557878	total: 6.91s	remaining: 141ms
# 980:	learn: 2218.0564227	total: 6.92s	remaining: 134ms
# 981:	learn: 2217.8557527	total: 6.92s	remaining: 127ms
# 982:	learn: 2217.5831860	total: 6.93s	remaining: 120ms
# 983:	learn: 2217.1432402	total: 6.94s	remaining: 113ms
# 984:	learn: 2216.7282468	total: 6.94s	remaining: 106ms
# 985:	learn: 2216.3941361	total: 6.95s	remaining: 98.7ms
# 986:	learn: 2215.9669864	total: 6.95s	remaining: 91.6ms
# 987:	learn: 2215.6944147	total: 6.96s	remaining: 84.5ms
# 988:	learn: 2215.1990639	total: 6.96s	remaining: 77.5ms
# 989:	learn: 2214.8184452	total: 6.97s	remaining: 70.4ms
# 990:	learn: 2214.3840744	total: 6.97s	remaining: 63.3ms
# 991:	learn: 2214.0930256	total: 6.98s	remaining: 56.3ms
# 992:	learn: 2213.8593387	total: 6.98s	remaining: 49.2ms
# 993:	learn: 2213.4675477	total: 6.99s	remaining: 42.2ms
# 994:	learn: 2213.0047897	total: 6.99s	remaining: 35.1ms
# 995:	learn: 2212.7846120	total: 7s	remaining: 28.1ms
# 996:	learn: 2212.5308566	total: 7s	remaining: 21.1ms
# 997:	learn: 2212.1924499	total: 7.02s	remaining: 14.1ms
# 998:	learn: 2211.8364381	total: 7.02s	remaining: 7.03ms
# 999:	learn: 2211.3541188	total: 7.03s	remaining: 0us

# %%
coeff_score = ctb.score(X_test,y_test)
coeff_score
# Out:
# 0.5536811963904913

# %% [markdown]
# # predicting the test data

# %%
X2=df2.drop(['Product_Identifier','Supermarket_Identifier','Product_Supermarket_Identifier','Product_Type','Product_Weight',
           'Supermarket_Opening_Year','Product_Fat_Content'], axis=1)
X2.head()
# Out:
#    Product_Shelf_Visibility  Product_Price  Supermarket _Size  \
# 0                  0.178246         395.32                  3
# 1                  0.061434         327.49                  3
# 2                  0.020573         391.16                  2
# 3                  0.080131         427.28                  3
# 4                  0.028710         395.40                  3
#
#    Supermarket_Location_Type  Supermarket_Type
# 0                          1                 3
# 1                          2                 2
# 2                          3                 3
# 3                          2                 2
# 4                          3                 3

# %%
test_pred = clf1.predict(X2) #predict on the test set for submission
df3= {'Product_Supermarket_Identifier': df2['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales': test_pred}
sub = pd.DataFrame(data=df3)
sub = sub[['Product_Supermarket_Identifier', 'Product_Supermarket_Sales']]

sub.to_csv('submission_recent.csv', index = False)
sub.head()
# Out:
#   Product_Supermarket_Identifier  Product_Supermarket_Sales
# 0              FDC15_CHUKWUDI049                6171.510254
# 1              NCY06_CHUKWUDI018                4258.343262
# 2              DRB24_CHUKWUDI035                6304.946777
# 3              NCG54_CHUKWUDI018                5686.457520
# 4              NCA42_CHUKWUDI017                6793.395020

# %% [markdown]
# Croos validation
